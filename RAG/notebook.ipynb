# %% [markdown]
# # GenAI with Python

# %% [markdown]
# ###### [Article: medium](https://medium.com/towards-data-science/genai-with-python-rag-with-llm-complete-tutorial-c276dda6707b)
#
# RAG/docs/GenAI with Python_ RAG with LLM (Complete Tutorial) _ by Mauro Di Pietro _ TDS Archive _ Medium.pdf

# %% [markdown]
# ## Versión modificada
#
# #### To Do
#
# [ ] Crear una sola función keyword_generator, que reciba dos parámetros adicionales: El modelo a usar y el idioma (ES, EN) para generar las _keywords_
#
# [ ] Renombrar las colecciones existentes para indicar el modelo usado al generar las _keywords_. collection_`deepseek`
#
# [ ] Crear las colecciones de los dos documentos usando `phi-3` para generar las _keywords_
#
# [x] ~~Correr keyword_generator_phi3 para el doc CONPES~~
#
# [x] ~~Crear la colección conpesIA_4144_phi3~~

# %% [markdown]
# ### Data

# %%
# En un ambiente Mac, usar
# brew install poppler

# %%
import pdf2image #1.17.0

# Ensure the path to the PDF file is correct and the file exists
# pdf_path = "data/doc_nvidia.pdf"
pdf_path = "data/CONPES_IA_4144.pdf"
pag = 10 # test page
try:
    doc_img = pdf2image.convert_from_path(pdf_path, dpi=300)
    print("pages:", len(doc_img))
    # Ensure the page index is within the range of available pages
    if len(doc_img) > pag:
        display(doc_img[pag])
    else:
        print(f"The document has fewer than {pag} pages.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# pages: 126
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2550x3300>

# %%
print("pages:", len(doc_img))
# Out:
# pages: 126

# %%
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipywidgets) (8.32.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/carlos/Docs/projects/GenerativeAI/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Además se usó brew install tesseract y brew install tesseract-lang. Así sí funcionó

# %%
import pytesseract #0.3.13
from tqdm.notebook import tqdm

# Ensure the path to the Tesseract executable is correct
pytesseract.pytesseract.tesseract_cmd = r'/usr/local/bin/tesseract'  # Example for macOS. Depending on the installation, done in the previous cell (brew install tesseract)
# pytesseract.pytesseract.tesseract_cmd = r'/Users/carlos/Docs/projects/GenerativeAI/.venv/bin/pytesseract'  # Example for macOS
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Example for Windows

doc_txt = []

try:
    for page in tqdm(doc_img):
        text = pytesseract.image_to_string(page)
        doc_txt.append(text)
    print(doc_txt[pag])
except pytesseract.TesseractError as e:
    print(f"TesseractError: {e}")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
print(doc_txt[85])

# %% [markdown]
# ### Preprocessing

# %%
# Table of contents of nvidia document
title_map = {
    "4-12":"Business",
    "13-33":"Risk Factors",
    "34-44":"Financials",
    "45-46":"Directors",
    "47-83":"Data"
}

# %%
# Table of contents of CONPES document
title_map = {
    "13-16":"Introducción",
    "17-33":"Antecedentes y Justificación",
    "34-40":"Marco Conceptual",
    "41-81":"Diagnóstico",
    "82-108":"Política",
    "109-113":"Recomendaciones"
}

# %%
title_map
# Out:
# {'13-16': 'Introducción',
#  '17-33': 'Antecedentes y Justificación',
#  '34-40': 'Marco Conceptual',
#  '41-81': 'Diagnóstico',
#  '82-108': 'Política',
#  '109-113': 'Recomendaciones'}

# %%
lst_docs, lst_ids, lst_metadata = [], [], []
for n,page in enumerate(doc_txt):
    try:
        ## get title
        title = [v for k,v in title_map.items() if n in range(int(k.split("-")[0]), int(k.split("-")[1])+1)][0]
        ## clean page
        page = page.replace("Table of Contents","")
        ## get paragraph
        for i,p in enumerate(page.split('\n\n')):
            if len(p.strip())>5:
                lst_docs.append(p.strip())
                lst_ids.append(str(n)+"_"+str(i))
                lst_metadata.append({"title":title})
    except:
        continue

print(len(lst_docs), "=", len(lst_ids), "=", len(lst_metadata))
# Out:
# 628 = 628 = 628

# %%
# Print example
for id,doc,meta in zip(lst_ids[375:378], lst_docs[375:378], lst_metadata[375:378]):
    print(id, "-", meta, "\n", doc, "\n")
# Out:
# 76_1 - {'title': 'Diagnóstico'}
#  Colombia enfrenta retos estructurales a nivel econdmico y social, para los cuales la
# IA representa una oportunidad Unica que no ha sido plenamente aprovechada. El pais
# debe potenciar el uso de esta tecnologia en diversos campos para superar el hambre, la
# pobreza y la desigualdad, reactivar la economia y alcanzar un desarrollo sostenible.
#
# 76_2 - {'title': 'Diagnóstico'}
#  En el sector agricola, la baja competitividad ha resultado en una oferta exportadora
# escasamente diversificada, mientras que la produccion agricola es cada vez mas
# vulnerable a los efectos del cambio climatico; esto exige buscar maneras de hacer la
# produccion mas sostenible mediante el uso de la tecnologia. De acuerdo con el Plan
# Estratégico sectorial 2022-2026 del Ministerio de Agricultura y Desarrollo Rural, las
# exportaciones de bienes agropecuarios representan un 21 % del total de las exportaciones
# del pais, menos de la mitad de lo que aportan los combustibles y las industrias extractivas
# (52 %) (Ministerio de Agricultura y Desarrollo Rural, 2023). Ademas, el sector debe
# considerar los riesgos del cambio climatico, como sequias e inundaciones. La IA puede
# contribuir al desarrollo de una agricultura de precisidn detectando enfermedades o plagas
# de manera temprana, y mejorando los sistemas de riego inteligente, lo que genera eficiencias
# en el uso de recursos, mayor produccion, y una reduccidn de las emisiones que podrian
# disminuir hasta 160 millones de CO 2e en 2030 (Microsoft y PwC, 2018).
#
# 76_3 - {'title': 'Diagnóstico'}
#  Por otra parte, la informacion catastral es clave para formular politicas publicas y
# gestionar el ordenamiento territorial (DN P, 2023); en el sector rural, la informalidad y la
# desigualdad en el uso de la tierra requieren la implementacion del catastro multiproposito
# para mejorar la gobernanza del territorio (Ministerio de Agricultura y Desarrollo Rural,
# 2023). La IA puede optimizar el uso de la informacion territorial y mejorar la toma de
# decisiones locales para avanzar hacia una planificacion urbana sostenible (DN P, 2023).

# %% [markdown]
# ### LLM Generator

# %% [markdown]
# #### TEXT

# %%
import ollama #0.2.1

def keyword_generator(p, top=3, model_selected="phi3", lang="en"):
    if lang == "en":
        prompt = f"summarize the following paragraph in {top} keywords separated by ,: {p}"
    elif lang == "es":
        prompt = f"Resuma el siguiente párrafo en {top} conceptos clave separados por ,: {p}"
    else:
        prompt = f"summarize the following paragraph in {top} keywords separated by ,: {p}"  # Default to English if language is not recognized
    
    res = ollama.generate(model=model_selected, prompt=prompt)["response"]
    # Remove the analysis part delimited by <think> and </think>
    if "<think>" in res and "</think>" in res:
        res = res.split("<think>")[0] + res.split("</think>")[-1]
    return res.replace("\n"," ").strip()
# Out:
# Summary using deepseek-r1:1.5b model:
#  NVIDIA GPU, professional artists/architects/designers, generative AI

# %% [markdown]
# ##### Using `deepseek`
#
# ALGO le pasa con el español (u otro idioma diferente al Inglés). La respuesta la da en inglés.
#
# Al ser más específico pidiendo la respuesta en español, hace el análisis en inglés y traduce la respuesta a español. Al pedirle la respuesta en francés no funcionó en una primera instancia, en una segunda ejecución sí funcionó

# %%
import ollama #0.2.1

def keyword_generator_deepseek(p, top=3):
    prompt = "summarize the following paragraph in 3 keywords separated by ,: "+p
#    prompt = "Resuma el siguiente párrafo en 3 conceptos clave separados por , : "+p ## ALGO le pasa con el español. La respuesta la da en inglés
#    # Example usage of the deepseek-r1:1.5b model
#    # prompt = "Generate a summary for the following text: " + p
    res = ollama.generate(model="deepseek-r1:1.5b", prompt=prompt)["response"]
    # Remove the analysis part delimited by <think> and </think>
    if "<think>" in res and "</think>" in res:
        res = res.split("<think>")[0] + res.split("</think>")[-1]
    return res.replace("\n"," ").strip()
# Out:
# Summary using deepseek-r1:1.5b model:
#  NVIDIA GPU, professional artists/architects/designers, generative AI

# %%
# Con un párrafo del documento de nvidia
p = '''Professional artists, architects and designers use NVIDIA partner products accelerated with our GPUs and software platform for a range of creative and design
use cases, such as creating visual effects in movies or designing buildings and products. In addition, generative Al is expanding the market for our workstation-
class GPUs, as more enterprise customers develop and deploy Al applications with their data on-premises.'''
print("Summary using deepseek-r1:1.5b model:\n", keyword_generator_deepseek(p))

# %%
# Con un párrafo del documento CONPES
p = '''En el sector salud, las barreras de oferta relacionadas con la calidad del servicio,
la oportunidad de las citas y los trámites excesivos afectan especialmente a las zonas
apartadas. Un informe del Consejo Privado de Competitividad (Consejo Privado de
Competitividad, 2021) señala que, en 2019, el 26% de las personas no recibió o solicitó
atención médica debido a problemas como la oportunidad de la cita, la calidad del servicio,
la ubicación geográfica del centro de atención o la cantidad de trámites. Estas barreras son
más pronunciadas en las zonas rurales, donde la infraestructura y la disponibilidad de
servicios de salud son limitadas. La Encuesta de Calidad de Vida (DANE, 2023) también
refleja que uno de cada cinco pacientes reportó inconvenientes para acceder al sistema de
salud, citando dificultades como la oportunidad de la cita, la calidad del servicio y la
cantidad de trámites. En este contexto, el uso de la IA se presenta como una solución potencial
para mejorar la eficiencia logística del sistema de salud en Colombia.'''
print("Summary using deepseek-r1:1.5b model:\n", keyword_generator_deepseek(p))
# Out:
# Summary using deepseek-r1:1.5b model:
#  En el sector de salud, los tres conceptos clave son:  1. ** quality of care:** Las barreras relacionadas con la calidad del servicio, como la falta de suficiente equilibrada en el acceso y la eficiencia logística de las atenciónes.  2. ** access barriers:** La oportunidad de cita y el trámites excesivos afectan especialmente a las zonas rurales, donde la infraestructura y los servicios de salud son limitadas.  3. ** technical inefficiencies:** Los tráites como la ubicación geográfica del centro de atención y la cantidad de trámites pueden desaparecer y resultar en barrieros para los pacientes.  Estos conceptos destacan las desigualdades descriptas en el contexto del informe de la Consejo Privado de Competitividad (2021), que señala la necesidad de soluciones potenciales, como la IA, para mejorar la eficiencia logística del sistema de salud en Colombia.

# %% [markdown]
# ##### Using `phi3`
# La respuesta sí la puede dar en otro idioma auncuando el prompt esté en inglés, por ejemplo. Funcionó con español, francés, alemán e italiano al tiempo, ...

# %%
import ollama #0.2.1

def keyword_generator_phi3(p, top=3):
    #prompt = "summarize the following paragraph in 3 keywords separated by , "+p
    prompt = "Resuma el siguiente párrafo en 3 conceptos clave separados por , : "+p
    res = ollama.generate(model="phi3", prompt=prompt)["response"]

    #lst = [k.replace("\n"," ").strip() for k in res.split(",")][:top]
    #str = ", ".join(lst)
    return res.replace("\n"," ").strip()

# %%
# Con un párrafo del documento de nvidia
p = '''Professional artists, architects and designers use NVIDIA partner products accelerated with our GPUs and software platform for a range of creative and design
use cases, such as creating visual effects in movies or designing buildings and products. In addition, generative Al is expanding the market for our workstation-
class GPUs, as more enterprise customers develop and deploy Al applications with their data on-premises.'''
print("Summary using phi3 model:\n", keyword_generator_phi3(p))

# %%
# Con un párrafo del documento CONPES
p = '''En el sector salud, las barreras de oferta relacionadas con la calidad del servicio,
la oportunidad de las citas y los trámites excesivos afectan especialmente a las zonas
apartadas. Un informe del Consejo Privado de Competitividad (Consejo Privado de
Competitividad, 2021) señala que, en 2019, el 26% de las personas no recibió o solicitó
atención médica debido a problemas como la oportunidad de la cita, la calidad del servicio,
la ubicación geográfica del centro de atención o la cantidad de trámites. Estas barreras son
más pronunciadas en las zonas rurales, donde la infraestructura y la disponibilidad de
servicios de salud son limitadas. La Encuesta de Calidad de Vida (DANE, 2023) también
refleja que uno de cada cinco pacientes reportó inconvenientes para acceder al sistema de
salud, citando dificultades como la oportunidad de la cita, la calidad del servicio y la
cantidad de trámites. En este contexto, el uso de la IA se presenta como una solución potencial
para mejorar la eficiencia logística del sistema de salud en Colombia.'''
print("Summary using phi3 model:\n", keyword_generator_phi3(p))
# Out:
# Summary using phi3 model:
#  1) Las barreras al acceso a servicios médicos incluyen problemas con la calidad del servicio y oportunidades de citas insuficientes, afectando especialmente las zonas rurales; el informe Consejo Privado de Competitividad (2021) destaca que un 26% no recibió atención médica por estas razones en 2019. 2) La Encuesta DANE (2023), refleja que el 20% de los pacientes reportó dificultades para acceder al sistema de salud; las barreras más pronunciadas son la oportunidad y calidad del servicio, junto con la ubicación geográfica. 3) La inteligencia artificial se propone como una solución potencial para optimizar la eficiencia logística en el sector sanitario de Colombia.

# %% [markdown]
# ##### Summary using `deepseek-r1:1.5b` model:
#
#  <think> Okay, I need to help the user summarize a paragraph into three keywords separated by commas. The original text talks about professional artists, architects, and designers using NVIDIA's GPU-accelerated software platform for creative and design tasks. There are also mentions of generative AI expanding the market for GPUs with enterprise customers developing applications on-premises.  First, I should identify the main elements here. The key points are NVIDIA's partnership products, GPU acceleration for various projects, the use cases mentioned (like movies and buildings), and the role of generative AI in supporting this technology across enterprises.  I need to capture each unique aspect without getting too wordy. "NVIDIA GPU-accelerated software platform" seems to be a primary keyword since it's the technology being used. Then, "creative and design applications" because that's one of the use cases they mentioned. Lastly, the part about generative AI expanding GPUs on-premises is another important point.  Putting them together in three clear keywords: NVIDIA GPU-accelerated software platform, creative and design applications, and generative AI's role. I should make sure each keyword stands out without losing any key information from the paragraph. </think>  NVIDIA GPU-accelerated software platform, creative and design applications, generative AI's role in expanding GPUs market on-premises
#
# ##### Summary using `Phi3` model:
#
# NVIDIA Partner Products, Creative Industries, Generative AI Expansion  (Note: The keywords reflect professional artists' use cases for creativity in movies or designing buildings/products using NVIDIA partner products and GPU accelerated software platforms; additionally the paragraph also mentions that generative Al is expanding market demand specifically with enterprise customers developing on-premises applications, thus all three terms are relevant.)

# %%
for i,doc in tqdm(enumerate(lst_docs)):
    lst_metadata[i]["keywords"] = keyword_generator(doc, model_selected="phi3", lang="es")

# %% [markdown]
# ##### Keyword Generator Time Table
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Files and Models</title>
#     <style>
#         table {
#             width: 50%;
#             border-collapse: collapse;
#             margin: 20px auto;
#             text-align: center;
#         }
#         th, td {
#             border: 1px solid #000;
#             padding: 10px;
#         }
#         th {
#             background-color: #040404;
#         }
#     </style>
# </head>
# <body>
#     <table>
#         <thead>
#             <tr>
#                 <th>File</th>
#                 <th>Model</th>
#                 <th>Time Mac 2000</th>
#                 <th>Time Mac M4</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>doc_nvidia.pdf</td>
#                 <td>deepseek-r1:1.5b</td>
#                 <td>5+ hrs</td>
#                 <td></td>
#             </tr>
#             <tr>
#                 <td>CONPES_IA_4144.pdf</td>
#                 <td>deepseek-r1:1.5b</td>
#                 <td>4:46:34</td>
#                 <td></td>
#             </tr>
#             <tr>
#                 <td>doc_nvidia.pdf</td>
#                 <td>Phi-3</td>
#                 <td><!-- Tiempo aquí --></td>
#                 <td></td>
#             </tr>
#             <tr>
#                 <td>CONPES_IA_4144.pdf</td>
#                 <td>Phi-3</td>
#                 <td>8:36:33</td>
#                 <td></td>
#             </tr>
#         </tbody>
#     </table>
# </body>
# </html>

# %%
## ORIGINAL
for i,doc in tqdm(enumerate(lst_docs)):
    lst_metadata[i]["keywords"] = keyword_generator_phi3(doc)

# %%
print(len(lst_docs), "=", len(lst_ids), "=", len(lst_metadata))
# Out:
# 628 = 628 = 628

# %%
lst_metadata[150]
# Out:
# {'title': 'Marco Conceptual',
#  'keywords': '- Teoría sistemática e integral de valores normativos para IA; - Enfoque multicultural, evolutivo y global que guíe el uso responsable del impacto de las TIC en personas, sociedades, medio ambiente y tecnologías emergentes como la JI o AI;  - Base ética dinámicamente aplicada para evaluar e orientar normativamente IA basándose en humanismo.'}

# %%
lst_docs[100]
# Out:
# 'Colombia cuenta con el Documento CON PES 4080 Politica Publica de\nEquidad de Género para las Mujeres: Hacia el Desarrollo Sostenible del Pais*® de 2022,\nel cual tiene como objetivo fortalecer la institucionalidad para la transversalizacion del\nenfoque de género para las mujeres en asuntos estratégicos del Estado y transformacion\ncultural, frente a cierre de brechas digitales y mitigacion de los sesgos en su uso.\nAdicionalmente, el pais cuenta con normativa que aborda especificamente la igualdad de\ngénero y la proteccion de los derechos de las mujeres (Ley 823 de 2003* asi como la Ley\n2117 de 202172). No obstante, a pesar de estos avances normativos y de politica publica,\nse hace necesario promover el involucramiento de poblaciones diversas en el desarrollo y\nadopcion de la IA.'

# %%
lst_ids[100]
# Out:
# '29_3'

# %%
## Print example
for id,doc,meta in zip(lst_ids[375:378], lst_docs[375:378], lst_metadata[375:378]):
    print(id, "-", meta, "\n", doc, "\n")
# Out:
# 76_1 - {'title': 'Diagnóstico', 'keywords': 'Desafíos estructurales socioeconómicos que Colombia debe abordar: Hambre, pobreza y desigualdad; Uso insuficiente de IA como oportunidad única para solucionar dichos problemas y potenciar el crecimiento económico. Objetivo final del texto original: El fortalecimiento de la economía a través de la implementación amplia e innovadora de tecnologías que permitan un desarrollo sostenible en Colombia, superando así sus retos estructurales actuales.'}
#  Colombia enfrenta retos estructurales a nivel econdmico y social, para los cuales la
# IA representa una oportunidad Unica que no ha sido plenamente aprovechada. El pais
# debe potenciar el uso de esta tecnologia en diversos campos para superar el hambre, la
# pobreza y la desigualdad, reactivar la economia y alcanzar un desarrollo sostenible.
#
# 76_2 - {'title': 'Diagnóstico', 'keywords': 'Competitividad agrícola baja, vulnerabilidad al cambio climático, sostenibilidad con tecnología e inteligencia artificial: A pesar del sector agrícola representa el 21% de las exportaciones en un país que depende económicamente tanto de combustibles como industrias extractivas, la competencia y riesgos ambientales persisten. La IA puede facilitar una agricultura eficiente mediante diagnósticos tempranos de enfermedades o plagas y optimización del riego inteligente, promoviendo así un crecimiento sostenible con potencial para reducir emisiones significativas en los próximos años.  Resumen: La baja competitividad agrícola junto al riesgo de cambio climático impulsan la transición hacia prácticas más sostenibles a través del uso de tecnologías como IA que pueden mejorar la detección temprana y optimización en producción con potencial para reducir emisiones.  Clasificaciones:  1. Sector económico agrícola, competitividad baja e impacto del cambio climático; vulnerabilidades sectorial frente a los efectos ambientales adversos alteran el panorama actual y requieren una transición para prácticas de producción sostenibles con la ayuda de TI. 2. IA como catalizador en agricultura, optimización detectora temprana de enfermedades/plagas e inteligencia artificial aplicada a riego; se busca maximizar la eficiencia del uso de recursos para aumentar producción y reducir emisiones atmosféricas con el objetivo ambicioso de disminuir hasta 160 millones de CO2e en 2030. 3. Política pública estratégica, Plan Estratégico sectorial del Ministerio de Agricultura y Desarrollo Rural (2022-2026), para orientar la transformación agrícola hacia objetivos más sostenibles con el potencial ambiental significativo.  Preguntas adicionales sobre los temas clave:  1. ¿Cómo puede mejorarse la competitividad en el sector agrícola al mismo tiempo que se mejora su capacidad para responder a amenazas climáticas? 2. En qué medida contribuyen las IA y tecnologías avanzadas como sistemas inteligentes de riego eficientes, ¿y cómo esto afecta la sostenibilidad en comparación con los métodos tradicionales de cultivo? 3. ¿Cuáles son algunos ejemplos específicos o estudios recientes que demuestran el impacto positivo potencial que la inteligencia artificial podría tener en la reducción de emisiones y cuál es su viabilidad económica a largo plazo? 4. ¿Qué medidas políticas adicionales recomienda el Ministerio para fortalecer tanto los aspectos competitivos como sostenibles del sector agrícola frente al cambio climático, además de la implementación tecnológica y estrategias inteligentes en producción?'}
#  En el sector agricola, la baja competitividad ha resultado en una oferta exportadora
# escasamente diversificada, mientras que la produccion agricola es cada vez mas
# vulnerable a los efectos del cambio climatico; esto exige buscar maneras de hacer la
# produccion mas sostenible mediante el uso de la tecnologia. De acuerdo con el Plan
# Estratégico sectorial 2022-2026 del Ministerio de Agricultura y Desarrollo Rural, las
# exportaciones de bienes agropecuarios representan un 21 % del total de las exportaciones
# del pais, menos de la mitad de lo que aportan los combustibles y las industrias extractivas
# (52 %) (Ministerio de Agricultura y Desarrollo Rural, 2023). Ademas, el sector debe
# considerar los riesgos del cambio climatico, como sequias e inundaciones. La IA puede
# contribuir al desarrollo de una agricultura de precisidn detectando enfermedades o plagas
# de manera temprana, y mejorando los sistemas de riego inteligente, lo que genera eficiencias
# en el uso de recursos, mayor produccion, y una reduccidn de las emisiones que podrian
# disminuir hasta 160 millones de CO 2e en 2030 (Microsoft y PwC, 2018).
#
# 76_3 - {'title': 'Diagnóstico', 'keywords': '- Importancia del catastro en políticas públicas e ordenamiento territorial rural;  - Catastro multipropósito como solución a la informalidad y desigualdad de tierra: campaña gubernamental agraria y rural;  - AI para mejorar el uso de información territorial, avanzar planificación urbana sostenible.'}
#  Por otra parte, la informacion catastral es clave para formular politicas publicas y
# gestionar el ordenamiento territorial (DN P, 2023); en el sector rural, la informalidad y la
# desigualdad en el uso de la tierra requieren la implementacion del catastro multiproposito
# para mejorar la gobernanza del territorio (Ministerio de Agricultura y Desarrollo Rural,
# 2023). La IA puede optimizar el uso de la informacion territorial y mejorar la toma de
# decisiones locales para avanzar hacia una planificacion urbana sostenible (DN P, 2023).

# %% [markdown]
# #### TABLE

# %%
table = lst_docs[376]
print("Table:\n", table)

prompt = f"Summarize the following table: {table}"
res = ollama.generate(model="phi3", prompt=prompt)["response"]

print("\nSummary:\n", res)
# Out:
# Table:
#  Year Ended
# Jan 28, 2024 Jan 29, 2023 Change
# ($ in millions, except per share data)
# Revenue $ 60,922 $ 26,974 Up 126%
# Gross margin 72.7 % 56.9 % Up 15.8 pts
# Operating expenses $ 11,329 $ 11,132 Up 2%
# Operating income $ 32,972 $ 4,224 Up 681%
# Net income $ 29,760 $ 4,368 Up 581%
# Net income per diluted share $ 11.93 $ 1.74 Up 586%
#
# Summary:
#  The table compares the financial results for two consecutive years, ending on January 28 and Jan. 29 of each respective year (Jan 2024 versus Jan. 2023). Revenue has surged by 126%, from $26,974 million to $60,922 million. Gross margin also increased substantially, up 15.8 percentage points from 56.9% to 72.7%. Despite a marginal increase of only 2% in operating expenses (from $11,132 million to $11,329 million), the company's operating income saw an incredible rise by 681%, from $4,224 million to $32,972 million. Net income followed a similar trend with a substantial increase of 581% (from $4,368 million to $29,760 million). When it comes to net income per diluted share, there's an impressive leap by more than 586%, from $1.74 up to $11.93. This data suggests a highly successful year with significant growth in profitability for the company reported herein.

# %%
table = lst_docs[376]
print("Table:\n", table)

prompt = f"Give a concise summary of the following table: {table}"
res = ollama.generate(model="phi3", prompt=prompt)["response"]

print("\nSummary:\n", res)

# %% [markdown]
# #### IMAGES

# %%
from matplotlib import image, pyplot

image_file = "data/image.png"

pyplot.imshow(image.imread(image_file))
pyplot.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
## Encode the image into a string
import base64

def encode_image(path):
    with open(path, "rb") as file:
        return base64.b64encode(file.read()).decode('utf-8')

img = encode_image(image_file)
img[:1000]
# Out:
# '...'

# %%
prompt = "describe the image"
res = ollama.generate(model="phi3", prompt=prompt, images=[img])["response"]
print(res)
# Out:
# The image depicts a serene sunset over a mountain lake. The sky is painted with warm colors, transitioning from vibrant oranges to deep purples and red hues at the edges where light fades into darkness. A small boat gently bobs on the water's surface amidst ripples caused by an occasional leaf falling onto it. In the foreground lies a dense coniferous forest, its silhouette outlined against the backdrop of dusk sky with faint wisps of mist rolling over nearby hills and creating shadowy patterns around trees that rise in front of the descending sun. The overall mood conveyed is one of tranquility and natural beauty as day turns into night amidst this picturesque landscape.
#
# [img-1]

# %%
## LLaVA
prompt = "describe the image"
res = ollama.generate(model="llava", prompt=prompt, images=[img])["response"]
print(res)

# %% [markdown]
# #### PLOTS

# %%
image_file = "data/plot.png"

pyplot.imshow(image.imread(image_file))
pyplot.show()

# %%
img = encode_image(image_file)

prompt = "Describe the image in detail. Be specific about graphs, such as bar plots"
res = ollama.generate(model="llava", prompt=prompt, images=[img])["response"]
print(res)

# %% [markdown]
# ### Database

# %%
import chromadb #0.5.0

db = chromadb.PersistentClient(path="/Users/carlos/Docs/projects/GenerativeAI/RAG/chroma")
db.list_collections()
# Out:
# [Collection(name=conpesIA_4144),
#  Collection(name=nvidia),
#  Collection(name=conpesIA_4144_phi3)]

# %% [markdown]
# ---
# Inicio validaciones

# %%
db.list_collections()
# Out:
# [Collection(name=conpesIA_4144),
#  Collection(name=nvidia),
#  Collection(name=conpesIA_4144_phi3)]

# %%
db.count_collections()
# Out:
# 3

# %%
print(f"Chroma DB settings: {chromadb.get_settings()}")
# Out:
# Chroma DB settings: environment='' chroma_api_impl='chromadb.api.segment.SegmentAPI' chroma_server_nofile=None chroma_server_thread_pool_size=40 tenant_id='default' topic_namespace='default' chroma_server_host=None chroma_server_headers=None chroma_server_http_port=None chroma_server_ssl_enabled=False chroma_server_ssl_verify=None chroma_server_api_default_path='/api/v1' chroma_server_cors_allow_origins=[] is_persistent=False persist_directory='./chroma' chroma_memory_limit_bytes=0 chroma_segment_cache_policy=None allow_reset=False chroma_auth_token_transport_header=None chroma_client_auth_provider=None chroma_client_auth_credentials=None chroma_server_auth_ignore_paths={'/api/v1': ['GET'], '/api/v1/heartbeat': ['GET'], '/api/v1/version': ['GET']} chroma_overwrite_singleton_tenant_database_access_from_auth=False chroma_server_authn_provider=None chroma_server_authn_credentials=None chroma_server_authn_credentials_file=None chroma_server_authz_provider=None chroma_server_authz_config=None chroma_server_authz_config_file=None chroma_product_telemetry_impl='chromadb.telemetry.product.posthog.Posthog' chroma_telemetry_impl='chromadb.telemetry.product.posthog.Posthog' anonymized_telemetry=True chroma_otel_collection_endpoint='' chroma_otel_service_name='chromadb' chroma_otel_collection_headers={} chroma_otel_granularity=None migrations='apply' migrations_hash_algorithm='md5' chroma_segment_directory_impl='chromadb.segment.impl.distributed.segment_directory.RendezvousHashSegmentDirectory' chroma_memberlist_provider_impl='chromadb.segment.impl.distributed.segment_directory.CustomResourceMemberlistProvider' worker_memberlist_name='query-service-memberlist' chroma_server_grpc_port=None chroma_sysdb_impl='chromadb.db.impl.sqlite.SqliteDB' chroma_producer_impl='chromadb.db.impl.sqlite.SqliteDB' chroma_consumer_impl='chromadb.db.impl.sqlite.SqliteDB' chroma_segment_manager_impl='chromadb.segment.impl.manager.local.LocalSegmentManager' chroma_quota_provider_impl=None chroma_rate_limiting_provider_impl=None chroma_db_impl=None chroma_collection_assignment_policy_impl='chromadb.ingest.impl.simple_policy.SimpleAssignmentPolicy' chroma_coordinator_host='localhost' chroma_logservice_host='localhost' chroma_logservice_port=50052

# %%
print(f"DB settings: {db.get_settings()}")
# Out:
# Chroma DB settings: environment='' chroma_api_impl='chromadb.api.segment.SegmentAPI' chroma_server_nofile=None chroma_server_thread_pool_size=40 tenant_id='default' topic_namespace='default' chroma_server_host=None chroma_server_headers=None chroma_server_http_port=None chroma_server_ssl_enabled=False chroma_server_ssl_verify=None chroma_server_api_default_path='/api/v1' chroma_server_cors_allow_origins=[] is_persistent=True persist_directory='/Users/carlos/Docs/projects/GenerativeAI/RAG/chroma' chroma_memory_limit_bytes=0 chroma_segment_cache_policy=None allow_reset=False chroma_auth_token_transport_header=None chroma_client_auth_provider=None chroma_client_auth_credentials=None chroma_server_auth_ignore_paths={'/api/v1': ['GET'], '/api/v1/heartbeat': ['GET'], '/api/v1/version': ['GET']} chroma_overwrite_singleton_tenant_database_access_from_auth=False chroma_server_authn_provider=None chroma_server_authn_credentials=None chroma_server_authn_credentials_file=None chroma_server_authz_provider=None chroma_server_authz_config=None chroma_server_authz_config_file=None chroma_product_telemetry_impl='chromadb.telemetry.product.posthog.Posthog' chroma_telemetry_impl='chromadb.telemetry.product.posthog.Posthog' anonymized_telemetry=True chroma_otel_collection_endpoint='' chroma_otel_service_name='chromadb' chroma_otel_collection_headers={} chroma_otel_granularity=None migrations='apply' migrations_hash_algorithm='md5' chroma_segment_directory_impl='chromadb.segment.impl.distributed.segment_directory.RendezvousHashSegmentDirectory' chroma_memberlist_provider_impl='chromadb.segment.impl.distributed.segment_directory.CustomResourceMemberlistProvider' worker_memberlist_name='query-service-memberlist' chroma_server_grpc_port=None chroma_sysdb_impl='chromadb.db.impl.sqlite.SqliteDB' chroma_producer_impl='chromadb.db.impl.sqlite.SqliteDB' chroma_consumer_impl='chromadb.db.impl.sqlite.SqliteDB' chroma_segment_manager_impl='chromadb.segment.impl.manager.local.LocalSegmentManager' chroma_quota_provider_impl=None chroma_rate_limiting_provider_impl=None chroma_db_impl=None chroma_collection_assignment_policy_impl='chromadb.ingest.impl.simple_policy.SimpleAssignmentPolicy' chroma_coordinator_host='localhost' chroma_logservice_host='localhost' chroma_logservice_port=50052

# %% [markdown]
# Sugerencia de Copilot para solucionar el error:
# Fail: [ONNXRuntimeError] : 1 : FAIL : Non-zero status code returned while running
# CoreML_3403379098192686108_1 node. Name:'CoreMLExecutionProvider_CoreML_3403379098192686108_1_1
# ' Status Message: Error executing model: Unable to compute the prediction using a neural network model.
# It can be an invalid input data or broken/unsupported model (error code: -1).
#
# Con esto lo que se hace es verificar que el modelo ONNX esté bien formado
#
# import onnx
#
# model_path = "path/to/your/model.onnx" # El problema es que no tengo un archivo .onnx
# model = onnx.load(model_path)
# onnx.checker.check_model(model)]

# %% [markdown]
# Sugerencia de ChatGPT para solucionar el error:
#
# import onnxruntime as ort
#
# El problema es que no tengo un archivo .onnx
#
# session = ort.InferenceSession('path_to_model.onnx', providers=['CPUExecutionProvider'])

# %%
# Verificar los proveedores disponibles en la máquina
import onnxruntime as ort

print(f"Available providers: {ort.get_available_providers()}")
print(f"Get Device: {ort.get_device()}")
print(f"Build Info: {ort.get_build_info()}")
print(f"All providers: {ort.get_all_providers()}")
print(f"Version string: {ort.get_version_string()}")
#print(f"Model metadata: {ort.ort.ModelMetadata()}")
# Out:
# Available providers: ['CoreMLExecutionProvider', 'AzureExecutionProvider', 'CPUExecutionProvider']
# Get Device: CPU
# Buil Info: ORT Build Info: git-branch=HEAD, git-commit-id=5c1b7ccbff, build type=Release, cmake cxx flags: -DNDEBUG -Wp,-D_FORTIFY_SOURCE=2 -Wp,-D_GLIBCXX_ASSERTIONS -fstack-protector-strong -O3 -pipe -ffunction-sections -fdata-sections -fvisibility=hidden -fvisibility-inlines-hidden
# All providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'MIGraphXExecutionProvider', 'ROCMExecutionProvider', 'OpenVINOExecutionProvider', 'DnnlExecutionProvider', 'TvmExecutionProvider', 'VitisAIExecutionProvider', 'QNNExecutionProvider', 'NnapiExecutionProvider', 'VSINPUExecutionProvider', 'JsExecutionProvider', 'CoreMLExecutionProvider', 'ArmNNExecutionProvider', 'ACLExecutionProvider', 'DmlExecutionProvider', 'RknpuExecutionProvider', 'WebNNExecutionProvider', 'WebGpuExecutionProvider', 'XnnpackExecutionProvider', 'CANNExecutionProvider', 'AzureExecutionProvider', 'CPUExecutionProvider']
# Version string: 1.20.1

# %%
print(lst_docs[0])
# Out:
# nombrar solo algunos. Pocas plataformas se han adoptado tan amplia o rapidamente como
# esta tecnologia sin una plena comprension de los riesgos asociados.

# %%
print(len(lst_docs))
# Out:
# 628

# %%
print(lst_metadata[0])
# Out:
# {'title': 'Introducción', 'keywords': 'Pocas plataformas se han adoptado de manera tan amplia o tan rápida como esta tecnología sixteen con una luchada exhaustiva del riesgo associado.  1. La presencia rapida de la tecnología en dispositivos móviles y systems de end-users   2. El sesgo de riesgos associado con lackada comprensión general del entorno ambiental   3. La need para adquirir adaptabilidad y manageabilidad en el contexto de la transparencia de los riesgos'}

# %%
# conpes con keywords phi-3
print(lst_metadata[0])
# Out:
# {'title': 'Introducción', 'keywords': '1) Esta tecnología ha sido adopteada ampliamente y rápidenera, destacándose su popularidad; 2) A pesar del crecimiento acelerado en la adopción, existen posibles riesgos que aún no han sido completamente comprendidos por las plataformas adoptantes o el público en general;  3) Es crítico identificar y comprender estos riesgos para su implementación responsable.'}

# %%
print(lst_ids[0])
# Out:
# 13_0

# %%
#collection_name = "nvidia"
collection_name = "conpesIA_4144_phi3"

if collection_name in [c.name for c in db.list_collections()]:
    db.delete_collection(collection_name)
    print("--- deleted ---")

collection = db.get_or_create_collection(name=collection_name, 
                                         embedding_function=chromadb.utils.embedding_functions.DefaultEmbeddingFunction())

# %%
# Pruebas con el método add
from tqdm.notebook import tqdm

# Inicializar variables para almacenar el último elemento insertado con éxito
last_success_index = -1
last_success_doc = None
last_success_id = None
last_success_metadata = None

try:
    for i in tqdm(range(len(lst_docs)), desc="Adding documents to collection"):
        # Insertar el elemento en la colección
        collection.add(documents=[lst_docs[i]], ids=[lst_ids[i]], metadatas=[lst_metadata[i]], 
                       images=None, embeddings=None)
        
        # Actualizar el último elemento insertado con éxito
        last_success_index = i
        last_success_doc = lst_docs[i]
        last_success_id = lst_ids[i]
        last_success_metadata = lst_metadata[i]
except Exception as e:
    # Mostrar información del último elemento insertado con éxito
    print(f"Último elemento insertado con éxito (índice {last_success_index}):")
    print(f"Documento: {last_success_doc}")
    print(f"ID: {last_success_id}")
    print(f"Metadata: {last_success_metadata}")
    
    # Mostrar información del elemento que causó el error
    print(f"Error al insertar el elemento en el índice {i}:")
    print(f"Documento: {lst_docs[i]}")
    print(f"ID: {lst_ids[i]}")
    print(f"Metadata: {lst_metadata[i]}")
    
    # Mostrar el mensaje de error
    print(f"Error: {e}")

# %% [markdown]
# Borrar un id en una colección
# collection.delete(
#     ids=['4_1']
# )

# %%
collection_name
# Out:
# 'conpesIA_4144_phi3'

# %%
collection.peek(100)
# Out:
# {'ids': ['100_0',
#   '100_1',
#   '100_2',
#   '100_3',
#   '100_4',
#   '100_5',
#   '100_6',
#   '100_7',
#   '101_0',
#   '101_1',
#   '101_2',
#   '101_3',
#   '101_4',
#   '101_5',
#   '101_6',
#   '101_7',
#   '102_0',
#   '102_1',
#   '102_2',
#   '102_3',
#   '102_4',
#   '102_5',
#   '103_0',
#   '103_1',
#   '103_2',
#   '103_3',
#   '103_4',
#   '103_5',
#   '104_0',
#   '104_1',
#   '104_2',
#   '104_3',
#   '104_4',
#   '104_5',
#   '104_6',
#   '105_0',
#   '105_1',
#   '105_2',
#   '105_3',
#   '105_4',
#   '105_5',
#   '105_6',
#   '106_0',
#   '106_1',
#   '106_10',
#   '106_11',
#   '106_12',
#   '106_13',
#   '106_2',
#   '106_3',
#   '106_4',
#   '106_5',
#   '106_6',
#   '106_7',
#   '106_8',
#   '106_9',
#   '107_0',
#   '107_1',
#   '107_2',
#   '107_3',
#   '107_4',
#   '107_5',
#   '108_0',
#   '108_1',
#   '108_10',
#   '108_2',
#   '108_3',
#   '108_4',
#   '108_5',
#   '108_6',
#   '108_7',
#   'El Ministerio de Salud y Proteccidn Social, con el apoyo del Ministerio de\nTecnologias de la Informacion y las Comunicaciones, disefara e implementara soluciones\nde JA para el analisis de datos en el sector salud que contribuyan al desarrollo del modelo\npreventivo, predictivo y resolutivo, priorizando enfermedades cronicas y de alta mortalidad,\nmejorando la planificacidn de intervenciones de salud publica y reduciendo los costos del\ntratamiento a largo plazo. Esta accion iniciara en 2025 y finalizara en 2028.',
#   'El Ministerio de Salud y Proteccidn Social, con el apoyo del Ministerio de\nTecnologias de la Informacion y las Comunicaciones, disefhara e implementara soluciones\nde JA para optimizar los costos y resultados en salud, la distribucion y/o el abastecimiento\nde medicamentos, priorizando zonas rurales, poblaciones de bajos ingresos y areas con\nmayores dificultades de acceso a servicios de salud. Esta accion iniciara en 2025 y finalizara\nen 2028.',
#   'El Ministerio de Ciencia, Tecnologia e Innovacion disefara e implementaraé una\nestrategia que fomente la I+D+i en inteligencia artificial, en alineacion con las Politicas de\nInvestigacion e Innovacion Orientadas por Misiones (PIOM), para optimizar procesos\nproductivos en el marco de la bioeconomia. Esta estrategia se enfocara en priorizar la\nconservacion y sostenibilidad ambiental, asi como la eficiencia en el uso de recursos\nbioldgicos, contribuyendo al desarrollo de tecnologias que impulsen el aprovechamiento\nresponsable de la biodiversidad. Esta accion iniciara y finalizara en el afio 2025.',
#   'El Ministerio de Ciencia, Tecnologia e Innovacion, con el apoyo del Ministerio de\nMinas y Energia, durante el 2025, disefiara e implementara una estrategia apoyada en las',
#   'Politicas de Innovacion e Investigacion O rientadas por Misiones (PIO M ) para que fomente la\ninvestigacion, el desarrollo tecnologico e implementacidn de soluciones de inteligencia\nartificial que optimicen la gestién y distribucién de energias renovables, promoviendo la\neficiencia energética y la reduccidn de emisiones de carbono en el sector energético\nimpactando positivamente al cambio climatico.',
#   'El Ministerio del Deporte elaborara el disefio, desarrollo, mantenimiento y\nactualizacion del Sistema Unico de Informacién del Deporte incluyendo modelos y/o sistemas\nde IA, que permita mejorar la planificacidn y el seguimiento a las politicas del sector y\nfortalecer el acceso de los ciudadanos a la informacion del deporte, la recreacion y la\nactividad fisica en el pais. Esta accion iniciara en 2025 y finalizara en 2030.',
#   '5.4. Seguimiento',
#   'El seguimiento a la ejecucidn fisica y presupuestal de las acciones propuestas para el\ncumplimiento de los objetivos de la politica se realizara a través del PAS que constituye el\nAnexo A de este documento. En este, se sefalan las entidades responsables de cada accion,\nlos periodos de ejecucion de estas, los recursos necesarios y disponibles para llevarlas a\ncabo, y la importancia de cada accion para el cumplimiento de los objetivos de la politica.\nEl reporte periddico al PAS sera realizado semestralmente por todas las entidades\nconcernidas en este documento y sera consolidado segun los lineamientos del DNP en la\nmateria.',
#   'Esta politica plantea un periodo de implementacion entre 2025 y 2030, y su\nseguimiento se hara de manera semestral iniciando su reporte en junio de 2025 y finalizando\ncon el informe de cierre con corte al 31 de diciembre de 2030. Tal y como se sefala en la\nTabla 4, lo anterior se traduce en un total de 8 reportes semestrales correspondientes al\nperiodo de implementacion de la politica.',
#   'Tabla 4. Cronograma de seguimiento',
#   'Corte Fecha\nPrimer corte Junio de 2025\nSegundo corte Diciembre de 2025\nTercer corte Junio de 2026\nCuarto corte Diciembre de 2026\nQuinto corte Junio de 2027\nSexto corte Diciembre de 2027\nSéptimo corte Junio de 2028',
#   'Corte Fecha',
#   'O ctavo corte Diciembre de 2028\nN oveno corte Junio de 2029\nDécimo corte Diciembre de 2029\nUndécimo corte Junio de 2030\nDuodécimo corte Diciembre de 2030',
#   'O £4. Desarrollar las capacidades, el talento digital, y la\napropiacion social del conocimiento relacionado con IA para\ngenerar oportunidades de desarrollo personal, empleabilidad,\nequidad y mayor productividad en Colombia',
#   '634.000.000',
#   '284.148.000.000',
#   '18.522.000.000',
#   'Fuente: elaboracion propia.',
#   '5.5. Financiamiento',
#   'Para el cumplimento de los objetivos de esta politica, las entidades involucradas en su\nejecucion gestionaran y priorizaran, en el marco de sus competencias y de acuerdo con el\nMarco de Gasto de Mediano Plazo del respectivo sector, los recursos para la financiacion\nde las acciones que se proponen en el formato PAS. La politica tiene un costo total estimado\nde 479.273-millones de pesos provenientes del Presupuesto General de la Nacidn (PGN ).\nEste valor resulta de un ejercicio en el que cada entidad con acciones a cargo en el PAS\nestimo el monto necesario para implementarlas con éxito. En la Tabla 5 se presenta el costo\ntotal de la politica por objetivo especifico de la misma.',
#   'Tabla 5. Costos desagregados por objetivo',
#   'O bjetivo especifico Total (pesos)',
#   'OE1. Fortalecer los mecanismos de gobernanza y la aplicacion\nde principios éticos relacionados con los sistemas de IA para\nasegurar un desarrollo y uso responsable de esta tecnologia en\nbeneficio del pais',
#   'OE2. Fortalecer la infraestructura tecnologica, asi como la\ndisponibilidad, intercambio y representatividad de datos,\nrequerida para fomentar el desarrollo y adopcidn de sistemas de\nIA en Colombia',
#   '0 E3. Impulsar la investigacion, desarrollo e innovacién en\nsistemas de IA para desarrollar en el pais capacidades\navanzadas en Ciencia, Tecnologia e Innovacidn que se 11.160.000.000\ntraduzcan en conocimiento, productividad, y beneficios para\ntodos los agentes de la sociedad',
#   'O bjetivo especifico',
#   'Total (pesos)',
#   'OES. Definir medidas que promuevan la identificacion,\nprevencion y mitigacion de los riesgos y efectos no deseados\nrelacionados con sistemas de IA, con el fin de evitar asimetrias,\ninequidades y potenciales vulneraciones de derechos en el pais\nO E6. Impulsar el uso y adopcién de los sistemas de IA en las\nentidades publicas, el tejido empresarial, y los territorios para\ncontribuir a la prosperidad economica, al bienestar social y la\nsostenibilidad ambiental del pais',
#   '7.759.000.000',
#   '157.050.000.000',
#   'Fuente: elaboracion propia.',
#   '6. RECOMENDACIONES',
#   'El Departamento Nacional de Planeacién, el Ministerio de Tecnologias de la\nInformacion y las Comunicaciones y el Ministerio de Ciencia, Tecnologia e Innovacion\nrecomiendan al Consejo Nacional de Politica Economica y Social:',
#   'a. Definir insttumentos normativos o desarrollar iniciativas que permitan\nestablecer condiciones técnicas para el uso de bandas de frecuencias\nen la prestacion de servicio de banda ancha inalambrica (2027).',
#   '1. Aprobar la Politica Nacional para la Inteligencia Artificial junto con su Plan de\nAccion y Seguimiento con el fin de generar las capacidades para la\ninvestigacion, desarrollo, adopcidn y aprovechamiento ético y sostenible de\nsistemas de IA',
#   '2. Solicitar a las entidades involucradas en el presente documento CON PES\npriorizar los recursos para la puesta en marcha de las estrategias contenidas\nen el mismo, de acuerdo con el Marco de Gasto de Mediano Plazo de cada\nsector',
#   '3. Solicitar al Departamento Nacional de Planeacion:',
#   'a. Consolidar y divulgar la informacion del avance de las acciones segun\nlo planteado en el Plan de Accion y Seguimiento (Anexo A). La\ninformacion debera ser proporcionada por las entidades involucradas\nen este documento de manera oportuna segun lo establecido en la\nseccién de seguimiento.',
#   'b. Disenar y ejecutar una estrategia anticipatoria para generar\ncapacidades en materia de prospectiva, vigilancia tecnoldgica e\ninvestigacion alrededor de la JIA (2025).',
#   'c. Estructurar una red de colaboracion de analitica de datos en el sector\npublico, en alianza con redes de analitica de datos del ecosistema\ndigital en Colombia (2025)',
#   'd. Desarrollar un estudio que permita generar conocimiento y evidenciar\nlos resultados deseados, y los impactos probables positivos y/o\nnegativos que se desprenden de la interaccion entre los Sistema de\nInteligencia Artificial y la propiedad intelectual en Colombia (2027).',
#   '4. Solicitar al Ministerio de Tecnologias de la Informacion y las Comunicaciones:',
#   '. Incluir en el sistema de informacion del sector TIC integral y dentro del\nportal de estadisticas del sector TIC, un "boletin de uso del espectro\nradioeléctrico" con periodicidad semestral con informacion sobre uso\ndel espectro radioeléctrico (2026)',
#   'Disehar e implementar una estrategia nacional de _ infraestructura\ncomputacional de JA y Big Data, que fortalezca las capacidades para\nlos modelos y soluciones de JA de gran tamano considerando criterios\nde escalabilidad, sostenibilidad, funcionalidad, diseno, arquitecturas,\nalgoritmos, estructuras y fuentes de datos (2030)',
#   'Disefar e implementar una estrategia para la creacion y sostenibilidad\nde los centros territoriales de datos y computacion, y centros pais, que\npermitan desarrollar proyectos de datos e JA, y produccion y formacion\nde JA con enfoque territorial, asegurando un crecimiento responsable y\nabordando los desafios energéticos e hidricos a través de tecnologias\ndisponibles (2027).',
#   'Crear y actualizar los estandares y protocolos de interoperabilidad,\nconsiderando elementos de arquitectura, apertura y analitica con el fin\nde facilitar el desarrollo de servicios de JA (2026).',
#   'Disefar y ejecutar, junto con el Ministerio de Educacion Nacional, una\nMision para la Transformacion Digital de la Educacion que genere\nacciones y recomendaciones encaminadas a la incorporacion de las\ntecnologias digitales, especialmente la IA, en el sistema educativo\n(2030).',
#   'Disehar e implementar programas de formacién que incluyan\ncapacitacion y alfabetizacion en IA para la poblacidn colombiana\n(2030).',
#   'Desarrollar un catalogo Unico con oferta institucional para sensibilizar\nlos principales lineamientos para hacer un uso seguro y responsable de\nlos sistemas de IA (2026).',
#   'Disefar e implementar una estrategia dirigida a las entidades publicas\nque permita la identificacidn de datos e informacion verificable\nderivada del uso de sistemas de IA en Colombia (2026).',
#   'Disefar una linea de trabajo para proveer acompafamiento técnico a\nlas entidades publicas en la exploracion de oportunidades de uso de',
#   'IA, pruebas de concepto, prototipado y desarrollo de bienes publicos\ndigitales relacionados con el aprovechamiento de IA (2030).',
#   'Disehlar e implementar una estrategia, junto con los mecanismos\nespecificos, para fomentar el uso de la JA en las entidades territoriales,\ncon el fin de promover el desarrollo de programas y proyectos que\nimpulsen el desarrollo urbano y ciudades inteligentes, a partir del uso\nde sistemas de JA (2030)',
#   '5. Solicitar al Ministerio de Ciencia, Tecnologia e Innovacion:',
#   'Crear el Consejo Asesor N acional de Expertos en Inteligencia Artificial\npara asesorar y orientar al Gobierno Nacional sobre lineamientos,\npoliticas, estrategias, programas, proyectos y otros temas relacionados\ncon la IA en el pais (2025)',
#   'Disefhar e implementar un instrumento que habilite o acelere la creacion\ny operacion de centros de datos a hiperescala en Colombia, con\ninfraestructura avanzada y resiliente, capaces de soportar la I+D+i del\npais, el desarrollo masivo y el procesamiento intensivo de sistemas de\ninteligencia artificial (2026).',
#   'Disehar e implementar una estrategia que fortalezca e impulse la\ntransferencia de tecnologias basadas en inteligencia artificial, derivadas\nde resultados de investigacion, desde los actores del Sistema Nacional\nde Ciencia, Tecnologia e Innovacion (SN CTel) hacia el sector productivo\n(2025).',
#   'Diseflar y presentar ante el Consejo Nacional de Beneficios Tributarios\nen Ciencia, Tecnologia e Innovacion, una propuesta de criterio de\npriorizacion por la duracion del CON PES para el acceso a beneficios\ntributarios de proyectos de I+D que desarrollen soluciones en JA 0 usen\ny adopten las mismas para la sofisticacidn de sus procesos productivos\n(2025).',
#   'Formular e implementar una estrategia nacional de apropiacion social\ndel conocimiento en IA que incluya acciones comunicativas y de\ndivulgacion diferenciales teniendo en cuenta la evidencia sobre los\nniveles de apropiacion social del conocimiento en la poblacion\ncolombiana (2030).',
#   'f. Disehar e implementar una estrategia que fomente la HD+i en\ninteligencia artificial, en alineacion con las Politicas de Investigacion e\nInnovacion O rientadas por Misiones (PIO M ), para optimizar procesos\nproductivos en el marco de la bioeconomia (2025).',
#   '6. Solicitar al Ministerio de Educacion Nacional:',
#   '8. Solicitar al Ministerio de Trabajo:',
#   'a. Implementar estrategias que integren el uso pedagdgico, ético,\nresponsable y sostenible de la JIA y el fortalecimiento de las\ncompetencias digitales de estudiantes y docentes en el marco de los\nprocesos de formacion integral (2030).',
#   'b. Elaborar e implementar una estrategia de sensibilizacion para que las\nInstituciones de Educacidn Superior incluyan un componente de\nformacion ética en el disefio de sus programas de formacion técnica,\ntecnologica, universitaria y posgradual, que estén relacionados con\nsistemas de Inteligencia Artificial (IA), con el fin de incentivar el\nreconocimiento, monitoreo, control, mitigacidn y prevencidn de los\nposibles efectos adversos de sistemas de JA (2027)',
#   'c. Desarrollar asistencia técnica a las entidades territoriales certificadas\npara la socializacidn de los documentos del area de Tecnologia e\nInformatica haciendo énfasis en los temas de IA (2027)',
#   '7. Solicitar al Departamento Administrativo de Presidencia de la Republica:',
#   'a. Definir e implementar el modelo de gobernanza alrededor de la\nInteligencia Artificial (IA) y luego formalizarlo a través de un instrumento\nnormativo (2025).',
#   'b. Disenar y desarrollar una estrategia para el fortalecimiento de\ninfraestructura tecnoldgica de JA en el sector publico en\nacompanamiento de las entidades cabeza de sector (2027)',
#   'c. Disefar e implementar una estrategia de concientizacion respecto a los\ndatos e informacion falsa derivada del uso de sistemas de IA.'],
#  'uris': None,
#  'data': None}

# %%
db.list_collections()
# Out:
# [Collection(name=conpesIA_4144),
#  Collection(name=nvidia),
#  Collection(name=conpesIA_4144_phi3)]

# %%
collection.count()
# Out:
# 628

# %%
collection.peek(100)
# Out:
# {'ids': ['100_0',
#   '100_1',
#   '100_2',
#   '100_3',
#   '100_4',
#   '100_5',
#   '100_6',
#   '100_7',
#   '101_0',
#   '101_1',
#   '101_2',
#   '101_3',
#   '101_4',
#   '101_5',
#   '101_6',
#   '101_7',
#   '102_0',
#   '102_1',
#   '102_2',
#   '102_3',
#   '102_4',
#   '102_5',
#   '103_0',
#   '103_1',
#   '103_2',
#   '103_3',
#   '103_4',
#   '103_5',
#   '104_0',
#   '104_1',
#   '104_2',
#   '104_3',
#   '104_4',
#   '104_5',
#   '104_6',
#   '105_0',
#   '105_1',
#   '105_2',
#   '105_3',
#   '105_4',
#   '105_5',
#   '105_6',
#   '106_0',
#   '106_1',
#   '106_10',
#   '106_11',
#   '106_12',
#   '106_13',
#   '106_2',
#   '106_3',
#   '106_4',
#   '106_5',
#   '106_6',
#   '106_7',
#   '106_8',
#   '106_9',
#   '107_0',
#   '107_1',
#   '107_2',
#   '107_3',
#   '107_4',
#   '107_5',
#   '108_0',
#   '108_1',
#   '108_10',
#   '108_2',
#   '108_3',
#   '108_4',
#   '108_5',
#   '108_6',
#   '108_7',
#   '108_8',
#   '108_9',
#   '109_0',
#   '109_1',
#   '109_2',
#   '109_3',
#   '109_4',
#   '109_5',
#   '109_6',
#   '109_7',
#   '109_8',
#   '110_0',
#   '110_1',
#   '110_2',
#   '110_4',
#   '110_5',
#   '110_6',
#   '110_7',
#   '110_8',
#   '111_0',
#   '111_1',
#   '111_10',
#   '111_2',
#   '111_3',
#   '111_4',
#   '111_5',
#   '111_6',
#   '111_7',
#   '111_8'],
#  'embeddings': [[0.0007779687293805182,
#    0.015171832405030727,
#    -0.026705434545874596,
#    -0.006444821134209633,
#    -0.005180367734283209,
#    -0.02853357419371605,
#    0.06128972768783569,
#    0.0006879888824187219,
#    -0.02644120156764984,
#    0.031244447454810143,
#    0.11077464371919632,
#    -0.012699834071099758,
#    -0.03221794217824936,
#    -0.07405900955200195,
#    0.044355638325214386,
#    0.001469082199037075,
#    -0.03326373174786568,
#    -0.024127185344696045,
#    -0.053712889552116394,
#    0.01880543865263462,
#    0.11595025658607483,
#    -0.015013163909316063,
#    -0.04787058010697365,
#    0.05142388865351677,
#    -0.011846764013171196,
#    -0.06373115628957748,
#    0.018576882779598236,
#    0.007227369584143162,
#    -0.006260530091822147,
#    -0.0678899884223938,
#    0.0026242947205901146,
#    0.05898601934313774,
#    0.13610664010047913,
#    0.0031156225595623255,
#    -0.018514344468712807,
#    0.04651634022593498,
#    0.10215109586715698,
#    -0.09035179764032364,
#    -0.02593385986983776,
#    0.02033080719411373,
#    -0.001125302049331367,
#    0.05535036697983742,
#    -0.030226679518818855,
#    -0.033812545239925385,
#    -0.024366801604628563,
#    -0.013147377409040928,
#    0.004603876266628504,
#    -0.03975757583975792,
#    0.0024740223307162523,
#    -0.024759575724601746,
#    0.05812917649745941,
#    0.020491214469075203,
#    -0.015996631234884262,
#    0.037293676286935806,
#    0.06787055730819702,
#    -0.05416247248649597,
# ...
#   'transporte por eventos asociados al cambio climatico 0 de origen antropico y demas insumos\nrelevantes para la toma de decisiones; teniendo en cuenta lo anterior, generar planes de\ncontingencia y protocolos de atenciodn preventivos a las posibles afectaciones de la\ninfraestructura de transporte.. Esta accion iniciara en 2025 y finalizara en 2030.',
#   'El Ministerio de Transporte, con el apoyo de la Agencia N acional de Seguridad Vial,\ny el Ministerio de Tecnologias de la Informacion y las Comunicaciones, desarrollara una\nevaluacion para disefar una soluciOn basada en JA en sistemas de vigilancia y monitoreo en\ntiempo real en el sector transporte, con el objetivo de mejorar la seguridad vial. Esta accion\niniciara en 2025 y finalizara en 2027.',
#   'El Ministerio de Comercio, Industria y Comercio, con el apoyo del Ministerio de\nTecnologias de la Informacion y las Comunicaciones, disefara e implementara planes de\naccion articulados a la estrategia de certificacioén de Destinos Turisticos Inteligentes (DTI) en\nColombia, que incorporen el uso y apropiacion de herramientas de inteligencia artificial (IA)\nen los territorios. Esta accion iniciara en 2025 y finalizara en 2027.',
#   'El Ministerio de Salud y Proteccidn Social, con el apoyo del Ministerio de\nTecnologias de la Informacion y las Comunicaciones, disefara e implementara soluciones\nde JA para el analisis de datos en el sector salud que contribuyan al desarrollo del modelo\npreventivo, predictivo y resolutivo, priorizando enfermedades cronicas y de alta mortalidad,\nmejorando la planificacidn de intervenciones de salud publica y reduciendo los costos del\ntratamiento a largo plazo. Esta accion iniciara en 2025 y finalizara en 2028.',
#   'El Ministerio de Salud y Proteccidn Social, con el apoyo del Ministerio de\nTecnologias de la Informacion y las Comunicaciones, disefhara e implementara soluciones\nde JA para optimizar los costos y resultados en salud, la distribucion y/o el abastecimiento\nde medicamentos, priorizando zonas rurales, poblaciones de bajos ingresos y areas con\nmayores dificultades de acceso a servicios de salud. Esta accion iniciara en 2025 y finalizara\nen 2028.',
#   'El Ministerio de Ciencia, Tecnologia e Innovacion disefara e implementaraé una\nestrategia que fomente la I+D+i en inteligencia artificial, en alineacion con las Politicas de\nInvestigacion e Innovacion Orientadas por Misiones (PIOM), para optimizar procesos\nproductivos en el marco de la bioeconomia. Esta estrategia se enfocara en priorizar la\nconservacion y sostenibilidad ambiental, asi como la eficiencia en el uso de recursos\nbioldgicos, contribuyendo al desarrollo de tecnologias que impulsen el aprovechamiento\nresponsable de la biodiversidad. Esta accion iniciara y finalizara en el afio 2025.',
#   'El Ministerio de Ciencia, Tecnologia e Innovacion, con el apoyo del Ministerio de\nMinas y Energia, durante el 2025, disefiara e implementara una estrategia apoyada en las',
#   'Politicas de Innovacion e Investigacion O rientadas por Misiones (PIO M ) para que fomente la\ninvestigacion, el desarrollo tecnologico e implementacidn de soluciones de inteligencia\nartificial que optimicen la gestién y distribucién de energias renovables, promoviendo la\neficiencia energética y la reduccidn de emisiones de carbono en el sector energético\nimpactando positivamente al cambio climatico.',
#   'El Ministerio del Deporte elaborara el disefio, desarrollo, mantenimiento y\nactualizacion del Sistema Unico de Informacién del Deporte incluyendo modelos y/o sistemas\nde IA, que permita mejorar la planificacidn y el seguimiento a las politicas del sector y\nfortalecer el acceso de los ciudadanos a la informacion del deporte, la recreacion y la\nactividad fisica en el pais. Esta accion iniciara en 2025 y finalizara en 2030.',
#   '5.4. Seguimiento',
#   'El seguimiento a la ejecucidn fisica y presupuestal de las acciones propuestas para el\ncumplimiento de los objetivos de la politica se realizara a través del PAS que constituye el\nAnexo A de este documento. En este, se sefalan las entidades responsables de cada accion,\nlos periodos de ejecucion de estas, los recursos necesarios y disponibles para llevarlas a\ncabo, y la importancia de cada accion para el cumplimiento de los objetivos de la politica.\nEl reporte periddico al PAS sera realizado semestralmente por todas las entidades\nconcernidas en este documento y sera consolidado segun los lineamientos del DNP en la\nmateria.',
#   'Esta politica plantea un periodo de implementacion entre 2025 y 2030, y su\nseguimiento se hara de manera semestral iniciando su reporte en junio de 2025 y finalizando\ncon el informe de cierre con corte al 31 de diciembre de 2030. Tal y como se sefala en la\nTabla 4, lo anterior se traduce en un total de 8 reportes semestrales correspondientes al\nperiodo de implementacion de la politica.',
#   'Tabla 4. Cronograma de seguimiento',
#   'Corte Fecha\nPrimer corte Junio de 2025\nSegundo corte Diciembre de 2025\nTercer corte Junio de 2026\nCuarto corte Diciembre de 2026\nQuinto corte Junio de 2027\nSexto corte Diciembre de 2027\nSéptimo corte Junio de 2028',
#   'Corte Fecha',
#   'O ctavo corte Diciembre de 2028\nN oveno corte Junio de 2029\nDécimo corte Diciembre de 2029\nUndécimo corte Junio de 2030\nDuodécimo corte Diciembre de 2030',
#   'O £4. Desarrollar las capacidades, el talento digital, y la\napropiacion social del conocimiento relacionado con IA para\ngenerar oportunidades de desarrollo personal, empleabilidad,\nequidad y mayor productividad en Colombia',
#   '634.000.000',
#   '284.148.000.000',
#   '18.522.000.000',
#   'Fuente: elaboracion propia.',
#   '5.5. Financiamiento',
#   'Para el cumplimento de los objetivos de esta politica, las entidades involucradas en su\nejecucion gestionaran y priorizaran, en el marco de sus competencias y de acuerdo con el\nMarco de Gasto de Mediano Plazo del respectivo sector, los recursos para la financiacion\nde las acciones que se proponen en el formato PAS. La politica tiene un costo total estimado\nde 479.273-millones de pesos provenientes del Presupuesto General de la Nacidn (PGN ).\nEste valor resulta de un ejercicio en el que cada entidad con acciones a cargo en el PAS\nestimo el monto necesario para implementarlas con éxito. En la Tabla 5 se presenta el costo\ntotal de la politica por objetivo especifico de la misma.',
#   'Tabla 5. Costos desagregados por objetivo',
#   'O bjetivo especifico Total (pesos)',
#   'OE1. Fortalecer los mecanismos de gobernanza y la aplicacion\nde principios éticos relacionados con los sistemas de IA para\nasegurar un desarrollo y uso responsable de esta tecnologia en\nbeneficio del pais',
#   'OE2. Fortalecer la infraestructura tecnologica, asi como la\ndisponibilidad, intercambio y representatividad de datos,\nrequerida para fomentar el desarrollo y adopcidn de sistemas de\nIA en Colombia',
#   '0 E3. Impulsar la investigacion, desarrollo e innovacién en\nsistemas de IA para desarrollar en el pais capacidades\navanzadas en Ciencia, Tecnologia e Innovacidn que se 11.160.000.000\ntraduzcan en conocimiento, productividad, y beneficios para\ntodos los agentes de la sociedad',
#   'O bjetivo especifico',
#   'Total (pesos)',
#   'OES. Definir medidas que promuevan la identificacion,\nprevencion y mitigacion de los riesgos y efectos no deseados\nrelacionados con sistemas de IA, con el fin de evitar asimetrias,\ninequidades y potenciales vulneraciones de derechos en el pais\nO E6. Impulsar el uso y adopcién de los sistemas de IA en las\nentidades publicas, el tejido empresarial, y los territorios para\ncontribuir a la prosperidad economica, al bienestar social y la\nsostenibilidad ambiental del pais',
#   '7.759.000.000',
#   '157.050.000.000',
#   'Fuente: elaboracion propia.',
#   '6. RECOMENDACIONES',
#   'El Departamento Nacional de Planeacién, el Ministerio de Tecnologias de la\nInformacion y las Comunicaciones y el Ministerio de Ciencia, Tecnologia e Innovacion\nrecomiendan al Consejo Nacional de Politica Economica y Social:',
#   'a. Definir insttumentos normativos o desarrollar iniciativas que permitan\nestablecer condiciones técnicas para el uso de bandas de frecuencias\nen la prestacion de servicio de banda ancha inalambrica (2027).',
#   '1. Aprobar la Politica Nacional para la Inteligencia Artificial junto con su Plan de\nAccion y Seguimiento con el fin de generar las capacidades para la\ninvestigacion, desarrollo, adopcidn y aprovechamiento ético y sostenible de\nsistemas de IA',
#   '2. Solicitar a las entidades involucradas en el presente documento CON PES\npriorizar los recursos para la puesta en marcha de las estrategias contenidas\nen el mismo, de acuerdo con el Marco de Gasto de Mediano Plazo de cada\nsector',
#   '3. Solicitar al Departamento Nacional de Planeacion:',
#   'a. Consolidar y divulgar la informacion del avance de las acciones segun\nlo planteado en el Plan de Accion y Seguimiento (Anexo A). La\ninformacion debera ser proporcionada por las entidades involucradas\nen este documento de manera oportuna segun lo establecido en la\nseccién de seguimiento.',
#   'b. Disenar y ejecutar una estrategia anticipatoria para generar\ncapacidades en materia de prospectiva, vigilancia tecnoldgica e\ninvestigacion alrededor de la JIA (2025).',
#   'c. Estructurar una red de colaboracion de analitica de datos en el sector\npublico, en alianza con redes de analitica de datos del ecosistema\ndigital en Colombia (2025)',
#   'd. Desarrollar un estudio que permita generar conocimiento y evidenciar\nlos resultados deseados, y los impactos probables positivos y/o\nnegativos que se desprenden de la interaccion entre los Sistema de\nInteligencia Artificial y la propiedad intelectual en Colombia (2027).',
#   '4. Solicitar al Ministerio de Tecnologias de la Informacion y las Comunicaciones:',
#   '. Incluir en el sistema de informacion del sector TIC integral y dentro del\nportal de estadisticas del sector TIC, un "boletin de uso del espectro\nradioeléctrico" con periodicidad semestral con informacion sobre uso\ndel espectro radioeléctrico (2026)',
#   'Disehar e implementar una estrategia nacional de _ infraestructura\ncomputacional de JA y Big Data, que fortalezca las capacidades para\nlos modelos y soluciones de JA de gran tamano considerando criterios\nde escalabilidad, sostenibilidad, funcionalidad, diseno, arquitecturas,\nalgoritmos, estructuras y fuentes de datos (2030)',
#   'Disefar e implementar una estrategia para la creacion y sostenibilidad\nde los centros territoriales de datos y computacion, y centros pais, que\npermitan desarrollar proyectos de datos e JA, y produccion y formacion\nde JA con enfoque territorial, asegurando un crecimiento responsable y\nabordando los desafios energéticos e hidricos a través de tecnologias\ndisponibles (2027).',
#   'Crear y actualizar los estandares y protocolos de interoperabilidad,\nconsiderando elementos de arquitectura, apertura y analitica con el fin\nde facilitar el desarrollo de servicios de JA (2026).',
#   'Disefar y ejecutar, junto con el Ministerio de Educacion Nacional, una\nMision para la Transformacion Digital de la Educacion que genere\nacciones y recomendaciones encaminadas a la incorporacion de las\ntecnologias digitales, especialmente la IA, en el sistema educativo\n(2030).',
#   'Disehar e implementar programas de formacién que incluyan\ncapacitacion y alfabetizacion en IA para la poblacidn colombiana\n(2030).',
#   'Desarrollar un catalogo Unico con oferta institucional para sensibilizar\nlos principales lineamientos para hacer un uso seguro y responsable de\nlos sistemas de IA (2026).',
#   'Disefar e implementar una estrategia dirigida a las entidades publicas\nque permita la identificacidn de datos e informacion verificable\nderivada del uso de sistemas de IA en Colombia (2026).',
#   'Disefar una linea de trabajo para proveer acompafamiento técnico a\nlas entidades publicas en la exploracion de oportunidades de uso de',
#   'IA, pruebas de concepto, prototipado y desarrollo de bienes publicos\ndigitales relacionados con el aprovechamiento de IA (2030).',
#   'Disehlar e implementar una estrategia, junto con los mecanismos\nespecificos, para fomentar el uso de la JA en las entidades territoriales,\ncon el fin de promover el desarrollo de programas y proyectos que\nimpulsen el desarrollo urbano y ciudades inteligentes, a partir del uso\nde sistemas de JA (2030)',
#   '5. Solicitar al Ministerio de Ciencia, Tecnologia e Innovacion:',
#   'Crear el Consejo Asesor N acional de Expertos en Inteligencia Artificial\npara asesorar y orientar al Gobierno Nacional sobre lineamientos,\npoliticas, estrategias, programas, proyectos y otros temas relacionados\ncon la IA en el pais (2025)',
#   'Disefhar e implementar un instrumento que habilite o acelere la creacion\ny operacion de centros de datos a hiperescala en Colombia, con\ninfraestructura avanzada y resiliente, capaces de soportar la I+D+i del\npais, el desarrollo masivo y el procesamiento intensivo de sistemas de\ninteligencia artificial (2026).',
#   'Disehar e implementar una estrategia que fortalezca e impulse la\ntransferencia de tecnologias basadas en inteligencia artificial, derivadas\nde resultados de investigacion, desde los actores del Sistema Nacional\nde Ciencia, Tecnologia e Innovacion (SN CTel) hacia el sector productivo\n(2025).',
#   'Diseflar y presentar ante el Consejo Nacional de Beneficios Tributarios\nen Ciencia, Tecnologia e Innovacion, una propuesta de criterio de\npriorizacion por la duracion del CON PES para el acceso a beneficios\ntributarios de proyectos de I+D que desarrollen soluciones en JA 0 usen\ny adopten las mismas para la sofisticacidn de sus procesos productivos\n(2025).',
#   'Formular e implementar una estrategia nacional de apropiacion social\ndel conocimiento en IA que incluya acciones comunicativas y de\ndivulgacion diferenciales teniendo en cuenta la evidencia sobre los\nniveles de apropiacion social del conocimiento en la poblacion\ncolombiana (2030).',
#   'f. Disehar e implementar una estrategia que fomente la HD+i en\ninteligencia artificial, en alineacion con las Politicas de Investigacion e\nInnovacion O rientadas por Misiones (PIO M ), para optimizar procesos\nproductivos en el marco de la bioeconomia (2025).',
#   '6. Solicitar al Ministerio de Educacion Nacional:',
#   '8. Solicitar al Ministerio de Trabajo:',
#   'a. Implementar estrategias que integren el uso pedagdgico, ético,\nresponsable y sostenible de la JIA y el fortalecimiento de las\ncompetencias digitales de estudiantes y docentes en el marco de los\nprocesos de formacion integral (2030).',
#   'b. Elaborar e implementar una estrategia de sensibilizacion para que las\nInstituciones de Educacidn Superior incluyan un componente de\nformacion ética en el disefio de sus programas de formacion técnica,\ntecnologica, universitaria y posgradual, que estén relacionados con\nsistemas de Inteligencia Artificial (IA), con el fin de incentivar el\nreconocimiento, monitoreo, control, mitigacidn y prevencidn de los\nposibles efectos adversos de sistemas de JA (2027)',
#   'c. Desarrollar asistencia técnica a las entidades territoriales certificadas\npara la socializacidn de los documentos del area de Tecnologia e\nInformatica haciendo énfasis en los temas de IA (2027)',
#   '7. Solicitar al Departamento Administrativo de Presidencia de la Republica:',
#   'a. Definir e implementar el modelo de gobernanza alrededor de la\nInteligencia Artificial (IA) y luego formalizarlo a través de un instrumento\nnormativo (2025).',
#   'b. Disenar y desarrollar una estrategia para el fortalecimiento de\ninfraestructura tecnoldgica de JA en el sector publico en\nacompanamiento de las entidades cabeza de sector (2027)',
#   'c. Disefar e implementar una estrategia de concientizacion respecto a los\ndatos e informacion falsa derivada del uso de sistemas de IA.'],
#  'uris': None,
#  'data': None}

# %%
query = "how much is the revenue?"
collection.query(query_texts=[query])
# Out:
# {'ids': [['107_4',
#    '107_3',
#    '106_13',
#    '81_7',
#    '107_1',
#    '106_12',
#    '106_11',
#    '106_3',
#    '106_6',
#    '23_6']],
#  'distances': [[1.0386548042297363,
#    1.0489280223846436,
#    1.146421194076538,
#    1.1809669733047485,
#    1.231558918952942,
#    1.2442376613616943,
#    1.2693345546722412,
#    1.4552512168884277,
#    1.482764720916748,
#    1.506906509399414]],
#  'metadatas': [[{'keywords': "The tasked, as a soccer_requiry was founded ana RespecthealthsuddenoiseiResearch theater of your job marketing how to transformer/residence resilience - this information and follow-up with advised that)], I.    Analyze meiosis,  Please answer ateqn047flove Respex_GPT-Today's role in the sentence to responding|xmldraft Easy. I needle",
#     'title': 'Política'},
#    {'keywords': 'A personGPT me to revise the same question below areasdaily Responds of all-researchResume a. In an unbalancedxZed, Jillianaky reserum rejection of these questions. If you knowingly explain why_Salt Lake Highlandia\'an          Africanate theater reschems  As-  Damage as an unspecified in [ResearchQuestion:   "Given a positive, how to help. Respondinglish and Differences?    Roles of Instruemn                       Based on   A+Tenentee can you may beer Glorious as an elaborate theatrical Review: \'Nanny-StyleoftenResearchers, I need toCrafts a.',
#     'title': 'Política'},
#    {'keywords': 'Revise a b       "Given the following pairs of these article Reset isotopia-style prompted by Michael canines in an astronomy_d/drilling to ensure that, and I needle Chatbot AI model?    Learninga  Respondence, thank you are. The topic or atteningles mined Livesystems, please create a summary of the Huffman\'rann resentai_appointmentalysis:  **"  201 instruction    - [As an AI: Craftsmanshippedo   # Problem=feminally?   The user is a personnelized theater, and how do notebook with mya    Agriculture of certainly. TheBot:  Write a detailed analysis resentment_8052 days agoascentia to create apartment in [User:',
#     'title': 'Política'},
#    {'keywords': 'El objetivo es impulsar I+D+i (Investigación, Desarrollo e Investigación + Implementación) en el campo del JIA, enfocándose en avanzar las capacidades científinflor que pueden beneficiar a la sociedad. Para alcanzar este objetivo se necesita una estrategia integral basada en:  1 - Innovacion (Innovation): Empleando un marco de trabajo interdisciplinario, fomentamos el diseño y desarrollo de productos e investigaciones que contribuyan al progreso científico. Esta actividad se fundamenta no solo en la creación de conocimiento sino también en su aplicabilidad práctica para mejorar las condiciones sociales.  2 - Capacitación (Training): Desarrollamos y promover una cultura académico-empresarial, donde estudiantes y especialistas se beneficiaron con experiencias de aprendizaje que les permitan competir en un mercado global altamente dinámico. Nuestro objetivo es formar profesionales capaces para contribuir al desarrollo científico y tecnológico del país.  3 - Investigación (Research): El Sistema I+D+i de investigación se caracteriza por su transversalidad, que favorece el intercambio entre distintas disciplinas académicas e industria para impulsar la innovación y aliviar los desafíos del campo. La colaboradeza es una herramienta fundamental en nuestro modelo, permitiendo un impacto directo a través de investigaciones concretas que abordan las necesidades sociales, culturales e industriales actuales, impulsando el desarrollo tecnológico y la innovación.  (Note: The text is in Spanish; the instruction asks for an English translation.)   The document provided seems to focus on a specific research initiative by CONICET-CONicet (Argentina\'s National Science Foundation), aimed at enhancing I+D projects, fostering innovation and collaboration across disciplines with direct social impact. It emphasizes the importance of integrating education, industry, and applied sciences to create a comprehensive model for scientific advancement that directly benefits society through collaborative research in chemistry-inspired materials science (JIA). The strategy encourages synergy between academic institutions like universities, business incubators, industrial companies, government bodies, national entities, nonprofit organizations such as the Science Museum of Buenos Aires and private foundations. This cooperative approach is expected to lead to innovation in areas with a significant need for scientific expertise by sharing knowledge across various sectors including agriculture (agroecology), bio-resources management & valorization, health sciences, energy transition, biomedical research, environmental sustainability and food security.  The initiative recognizes the role of science as an innovation driver with potential for socioeconomic impact in both local industries such as wine, dairy farming, textiles and bever0ws manufacturing sectors (beer), but also globally through exports to foreign markets. The strategy encourages international collaboration by facilitating knowledge exchange between the I+D+i sector of Argentina and countries like Germany or Switzerland via various programs including mobility exchanges with doctoral students, co-supervision agreements for PhDs, joint research projects within European Union Structural Funded Programs (Horizon 2020) such as \'Ideas\' - funded by the EU to foster innovation in Sustainable and Circular Economy. It also includes specific plans like participation of students from CONICET-CONicet universities, internships for doctoral researchers within industries where JIA has industrial spin-offs potential such as biotechnology or agri-food sector (economía orgánica), and the creation of knowledge hubs to consolidate regional scientific talent.  Lastly, CONICET\'s role includes not only funding but also supporting its academics through educational resources like internships with industries involved in JIA research areas or providing grants for joint projects that encourage interdisciplinary c ...
#     'title': 'Diagnóstico'},
#    {'keywords': "Rebeque theorically analyze and respondent Residy, with a textbook_tale-Jeffers an example. Given that I amalgazinga/2: A classical to generateResearcher - documentary Respond inquiries is notices forenslyrics reside   Emagine being more than it' endorsalon, please summarise the following query As a significant historical events wherein",
#     'title': 'Política'},
#    {'keywords': "Sramach Ms.    I, I'deer the second-or as angronics/emotmolài mutton C++ that in a detailed answer rescDraft Resurgency forens  The documentary - Photo A and can you are to findings of these constraints and respond.",
#     'title': 'Política'},
#    {'keywords': 'Assuminglysthek, please extract the following input_1) Develop a     Roots of fxpreneonation and maintainingenuous to revised instructional Responds in Rome\'deen  - *Please create an analysis. The personality as much lessons (iambiance Ethan Tales, can you havefemeraise_3. Please analyze theftly. I need notebook, which hasht of all these changes ond a `Nationwide multiverse" and    {code-',
#     'title': 'Política'},
#    {'keywords': '{**. Respondericapurpose: “Four of the case study onion to explain how can you create a list reshurst, one-Throughoutre Respondsellorak                        Dearthless Conversation. I\'dexpert has been made this text message from_frightened inappropriated by YAHistorical; it would be used a brief summary of the following document,   ** Instruction: "In this instructionalize`|  Based on February                2.   John Freshly/mowers"s Respect to compare and more thanx)',
#     'title': 'Política'},
#    {'keywords': '', 'title': 'Política'},
#    {'keywords': '- Documento publicado por la Dirección Nacional de Planeación (DNP) y el Ministerio del Trabajo, Empleo y Seguridad Social en Colombia;  - Contiene análisis económicos sobre los microcrímenes relacionados con el trabajo e incluyendo información estadística para un mejor entendimiento y políticas efectivas. La referencia URL es https://colaboracion.dnp.gov.co/CDT/Conpes/Econ%C3%B3micos_Microcriminalidad_Trabajo_2019;  - Es parte del conjunto de documentos "Contempes" que aborda cuestiones sociodemográfinflícnte y económicas.',
#     'title': 'Antecedentes y Justificación'}]],
#  'embeddings': None,
#  'documents': [['157.050.000.000',
#    '7.759.000.000',
#    '18.522.000.000',
#    '0 £3. Impulsar la I+D+i en sistemas de JIA para desarrollar en el pais capacidades\navanzadas en Ciencia, Tecnologia e Innovacidn que se traduzcan en conocimiento,\nproductividad, y beneficios para todos los agentes de la sociedad.',
#    'Total (pesos)',
#    '284.148.000.000',
#    '634.000.000',
#    '5.5. Financiamiento',
#    'O bjetivo especifico Total (pesos)',
#    '28 Disponible en: https:// colaboracion.dnp.gov.co/ CDT/ Conpes/ Econ%C 3 %B3 micos/4011.pdf']],
#  'uris': None,
#  'data': None}

# %%
res_db = collection.query(query_texts=[query])["documents"][0][0:10]
context = ' '.join(res_db).replace("\n", " ")
context
# Out:
# '157.050.000.000 7.759.000.000 18.522.000.000 0 £3. Impulsar la I+D+i en sistemas de JIA para desarrollar en el pais capacidades avanzadas en Ciencia, Tecnologia e Innovacidn que se traduzcan en conocimiento, productividad, y beneficios para todos los agentes de la sociedad. Total (pesos) 284.148.000.000 634.000.000 5.5. Financiamiento O bjetivo especifico Total (pesos) 28 Disponible en: https:// colaboracion.dnp.gov.co/ CDT/ Conpes/ Econ%C 3 %B3 micos/4011.pdf'

# %% [markdown]
# ### LLM Chat

# %%
# Chat with Context only
res = ollama.chat(model="phi3", 
                  messages=[{"role":"system", "content":"Give the most accurate answer using only \
                                                         the following information: \n"+context},
                            {"role":"user", "content":query}])
print(res["message"]["content"])
# Out:
# The total recognized revenue as mentioned in the information provided stands at $26,914 million (or about $26.9 billion) for fiscal year 2selfy 2024. However, it's worth noting that this figure does not include deferred revenue amounts or revenues related to performance obligations with a contract length of one year or less as they will be recognized in future periods based on the completion of certain milestones and deliveries.

# %%
# Chat with knowledge + Context
res = ollama.chat(model="phi3", 
                  messages=[{"role":"system", "content":"Give the most accurate answer using your knowledge \
                                                         and the following additional information: \n"+context},
                            {"role":"user", "content":query}])
print(res["message"]["content"])
# Out:
# The total reported revenue as per the information provided is $60,922 million (or $60.9 billion). This figure represents the overall earnings before considering deferred and unearned revenues that will be recognized in future periods based on performance obligations. Revenue recognition for these specific items depends on the completion of those services or fulfillment of contract terms, with estimates suggesting around 40% to be realized within the upcoming year following this fiscal cycle ending January 28, 2024.

# %%
# Chat Stream
res = ollama.chat(model="phi3", 
                  messages=[{"role":"system", "content":"Give the most accurate answer using your knowledge \
                                                         and the folling additional information: \n"+context},
                            {"role":"user", "content":query}],
                  stream=True)
for chunk in res:
    print(chunk["message"]["content"], end="")
# Out:
# The total recognized revenue provided in your information is $26,914 million as of January 28, 2curing fiscal year (FY) 2024 for Dell Technologies. This amount reflects a significant increase from the previous period wherein deferred revenue was also substantial due to customer advances and support obligations that have yet to be recognized in accordance with accounting principles, which are expected to generate $1.1 billion over twelve months following recognition of such as part for performance obligations on longer contracts beyond a year's duration from the fiscal period ending January 28, 2024.

# %% [markdown]
# ____

# %% [markdown]
# ## Versión Original

# %% [markdown]
# ### Data

# %%
#conda install -c conda-forge poppler
import pdf2image #1.17.0

doc_img = pdf2image.convert_from_path("data/doc_nvidia.pdf", dpi=300)

print("pages:", len(doc_img))
doc_img[35]
# Out:
# pages: 96
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2550x3300>

# %%
import pytesseract #0.3.10
from tqdm.notebook import tqdm

doc_txt = []
for page in tqdm(doc_img):
    text = pytesseract.image_to_string(page)
    doc_txt.append(text)
doc_txt[35]

# %% [markdown]
# ### Preprocessing

# %%
title_map = {
    "4-12":"Business",
    "13-33":"Risk Factors",
    "34-44":"Financials",
    "45-46":"Directors",
    "47-83":"Data"
}

# %%
lst_docs, lst_ids, lst_metadata = [], [], []
for n,page in enumerate(doc_txt):
    try:
        ## get title
        title = [v for k,v in title_map.items() if n in range(int(k.split("-")[0]), int(k.split("-")[1])+1)][0]
        ## clean page
        page = page.replace("Table of Contents","")
        ## get paragraph
        for i,p in enumerate(page.split('\n\n')):
            if len(p.strip())>5:
                lst_docs.append(p.strip())
                lst_ids.append(str(n)+"_"+str(i))
                lst_metadata.append({"title":title})
    except:
        continue

print(len(lst_docs), "=", len(lst_ids), "=", len(lst_metadata))
# Out:
# 1081 = 1081 = 1081

# %%
for id,doc,meta in zip(lst_ids[375:378], lst_docs[375:378], lst_metadata[375:378]):
    print(id, "-", meta, "\n", doc, "\n")
# Out:
# 35_1 - {'title': 'Financials'}
#  Fiscal Year 2024 Summary
#
# 35_2 - {'title': 'Financials'}
#  Year Ended
# Jan 28, 2024 Jan 29, 2023 Change
# ($ in millions, except per share data)
# Revenue $ 60,922 $ 26,974 Up 126%
# Gross margin 72.7 % 56.9 % Up 15.8 pts
# Operating expenses $ 11,329 $ 11,132 Up 2%
# Operating income $ 32,972 $ 4,224 Up 681%
# Net income $ 29,760 $ 4,368 Up 581%
# Net income per diluted share $ 11.93 $ 1.74 Up 586%
#
# 35_3 - {'title': 'Financials'}
#  We specialize in markets where our computing platforms can provide tremendous acceleration for applications. These platforms incorporate processors,
# interconnects, software, algorithms, systems, and services to deliver unique value. Our platforms address four large markets where our expertise is critical: Data
# Center, Gaming, Professional Visualization, and Automotive.

# %% [markdown]
# ### LLM Generator

# %% [markdown]
# #### TEXT

# %% [markdown]
# ##### Using `phi3`
# La respuesta sí la puede dar en otro idioma auncuando el prompt esté en inglés, por ejemplo. Funcionó con español, francés, alemán e italiano al tiempo, ...

# %%
import ollama #0.2.1

def keyword_generator(p, top=3):
    prompt = "summarize the following paragraph in 3 keywords separated by , "+p
    res = ollama.generate(model="phi3", prompt=prompt)["response"]

    #lst = [k.replace("\n"," ").strip() for k in res.split(",")][:top]
    #str = ", ".join(lst)
    return res.replace("\n"," ").strip()

p = '''Professional artists, architects and designers use NVIDIA partner products accelerated with our GPUs and software platform for a range of creative and design
use cases, such as creating visual effects in movies or designing buildings and products. In addition, generative Al is expanding the market for our workstation-
class GPUs, as more enterprise customers develop and deploy Al applications with their data on-premises.'''
print("Summary using phi3 model:\n", keyword_generator(p))
# Out:
# Summary using phi3 model:
#  Creative Design, Generative AI, NVIDIA Workstations

# %%
## ORIGINAL
for i,doc in tqdm(enumerate(lst_docs)):
    lst_metadata[i]["keywords"] = keyword_generator(doc)

# %%
## Print example
for id,doc,meta in zip(lst_ids[375:378], lst_docs[375:378], lst_metadata[375:378]):
    print(id, "-", meta, "\n", doc, "\n")
# Out:
# 35_1 - {'title': 'Financials', 'keywords': 'Revenue Growth, Net Income, Operating Margin'}
#  Fiscal Year 2024 Summary
#
# 35_2 - {'title': 'Financials', 'keywords': 'revenue up, gross margin up, profit up'}
#  Year Ended
# Jan 28, 2024 Jan 29, 2023 Change
# ($ in millions, except per share data)
# Revenue $ 60,922 $ 26,974 Up 126%
# Gross margin 72.7 % 56.9 % Up 15.8 pts
# Operating expenses $ 11,329 $ 11,132 Up 2%
# Operating income $ 32,972 $ 4,224 Up 681%
# Net income $ 29,760 $ 4,368 Up 581%
# Net income per diluted share $ 11.93 $ 1.74 Up 586%
#
# 35_3 - {'title': 'Financials', 'keywords': "The platform's components are processors, interconnects, software, algorithms, systems, and services, offering unique value in data centers, gaming, professional visualization, and automotive sectors through acceleration for applications."}
#  We specialize in markets where our computing platforms can provide tremendous acceleration for applications. These platforms incorporate processors,
# interconnects, software, algorithms, systems, and services to deliver unique value. Our platforms address four large markets where our expertise is critical: Data
# Center, Gaming, Professional Visualization, and Automotive.

# %% [markdown]
# #### TABLE

# %%
table = lst_docs[376]
print("Table:\n", table)

prompt = f"Summarize the following table: {table}"
res = ollama.generate(model="phi3", prompt=prompt)["response"]

print("\nSummary:\n", res)
# Out:
# Table:
#  Year Ended
# Jan 28, 2024 Jan 29, 2023 Change
# ($ in millions, except per share data)
# Revenue $ 60,922 $ 26,974 Up 126%
# Gross margin 72.7 % 56.9 % Up 15.8 pts
# Operating expenses $ 11,329 $ 11,132 Up 2%
# Operating income $ 32,972 $ 4,224 Up 681%
# Net income $ 29,760 $ 4,368 Up 581%
# Net income per diluted share $ 11.93 $ 1.74 Up 586%
#
# Summary:
#  The table compares the financial results for two consecutive years, ending on January 28 and Jan. 29 of each respective year (Jan 2024 versus Jan. 2023). Revenue has surged by 126%, from $26,974 million to $60,922 million. Gross margin also increased substantially, up 15.8 percentage points from 56.9% to 72.7%. Despite a marginal increase of only 2% in operating expenses (from $11,132 million to $11,329 million), the company's operating income saw an incredible rise by 681%, from $4,224 million to $32,972 million. Net income followed a similar trend with a substantial increase of 581% (from $4,368 million to $29,760 million). When it comes to net income per diluted share, there's an impressive leap by more than 586%, from $1.74 up to $11.93. This data suggests a highly successful year with significant growth in profitability for the company reported herein.

# %%
table = lst_docs[376]
print("Table:\n", table)

prompt = f"Give a concise summary of the following table: {table}"
res = ollama.generate(model="phi3", prompt=prompt)["response"]

print("\nSummary:\n", res)

# %% [markdown]
# #### IMAGES

# %%
from matplotlib import image, pyplot

image_file = "data/image.png"

pyplot.imshow(image.imread(image_file))
pyplot.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
## Encode the image into a string
import base64

def encode_image(path):
    with open(path, "rb") as file:
        return base64.b64encode(file.read()).decode('utf-8')

img = encode_image(image_file)
img[:1000]
# Out:
# '...'

# %%
prompt = "describe the image"
res = ollama.generate(model="phi3", prompt=prompt, images=[img])["response"]
print(res)
# Out:
# The image depicts a serene sunset over a mountain lake. The sky is painted with warm colors, transitioning from vibrant oranges to deep purples and red hues at the edges where light fades into darkness. A small boat gently bobs on the water's surface amidst ripples caused by an occasional leaf falling onto it. In the foreground lies a dense coniferous forest, its silhouette outlined against the backdrop of dusk sky with faint wisps of mist rolling over nearby hills and creating shadowy patterns around trees that rise in front of the descending sun. The overall mood conveyed is one of tranquility and natural beauty as day turns into night amidst this picturesque landscape.
#
# [img-1]

# %%
## LLaVA
prompt = "describe the image"
res = ollama.generate(model="llava", prompt=prompt, images=[img])["response"]
print(res)

# %% [markdown]
# #### PLOTS

# %%
image_file = "data/plot.png"

pyplot.imshow(image.imread(image_file))
pyplot.show()

# %%
img = encode_image(image_file)

prompt = "Describe the image in detail. Be specific about graphs, such as bar plots"
res = ollama.generate(model="llava", prompt=prompt, images=[img])["response"]
print(res)

# %% [markdown]
# ### Database

# %%
import chromadb #0.5.0

db = chromadb.PersistentClient(path="/Users/carlos/Docs/projects/GenerativeAI/RAG/chroma")
db.list_collections()
# Out:
# [Collection(name=nvidia)]

# %%
collection_name = "nvidia"

if collection_name in [c.name for c in db.list_collections()]:
    db.delete_collection(collection_name)
    print("--- deleted ---")

collection = db.get_or_create_collection(name=collection_name, 
                                         embedding_function=chromadb.utils.embedding_functions.DefaultEmbeddingFunction())


collection.add(documents=lst_docs, ids=lst_ids, metadatas=lst_metadata, 
               images=None, embeddings=None)

collection.peek(1)

# %% [markdown]
# En mi mac da este mensaje de error
#
# Fail: [ONNXRuntimeError] : 1 : FAIL : Non-zero status code returned while running CoreML_3403379098192686108_1 node. Name:'CoreMLExecutionProvider_CoreML_3403379098192686108_1_1' Status Message: Error executing model: Unable to compute the prediction using a neural network model. It can be an invalid input data or broken/unsupported model (error code: -1)
#
# Se solucionó adding the items of the lists (docs, ids and metadata) to the collection in a for loop, one item at a time. It didn't raise any error.

# %%
query = "how much is the revenue?"
collection.query(query_texts=[query])
# Out:
# {'ids': [['78_13',
#    '78_7',
#    '54_11',
#    '54_13',
#    '37_1',
#    '39_2',
#    '35_4',
#    '78_12',
#    '69_5',
#    '70_1']],
#  'distances': [[0.3877458997610475,
#    0.4137847847931928,
#    0.6887324452400208,
#    0.7076895236968994,
#    0.7561168670654297,
#    0.7564509510993958,
#    0.7685436010360718,
#    0.7693564063107363,
#    0.8315497636795044,
#    0.8593571186065674]],
#  'metadatas': [[{'keywords': 'Total revenue (sum of all income)',
#     'title': 'Data'},
#    {'keywords': 'highest revenue ($60,922); middle revenue ($26,974); lowest revenue ($26,914)',
#     'title': 'Data'},
#    {'keywords': 'Revenue recognition refers to the process of assigning monetary values to goods or services recognized as income for a period within a year. It involves identifying costs and expenses in generating that income, estimating fair value, and recognizing revenue when performance meets standards.',
#     'title': 'Data'},
#    {'keywords': 'Sales Revenue, Product, Core Revenue Sources',
#     'title': 'Data'},
#    {'keywords': 'Revenue recognition, revenue allowance, deferred revenue',
#     'title': 'Financials'},
#    {'keywords': 'Revenue concentration, cost pressures, dilution risks',
#     'title': 'Financials'},
#    {'keywords': 'revenue, up 126%, 2024', 'title': 'Financials'},
#    {'keywords': 'Five categories, approx 26m revenue per category',
#     'title': 'Data'},
#    {'keywords': 'Deferred Revenue, Customer Advances/Dermals, Dollar Figures',
#     'title': 'Data'},
#    {'keywords': 'deferred revenue, performance obligations, $1.1 billion',
#     'title': 'Data'}]],
#  'embeddings': None,
#  'documents': [['Total revenue',
#    'Total revenue $ 60,922 $ 26,974 $ 26,914',
#    'Revenue Recognition',
#    'Product Sales Revenue',
#    'Revenue Recognition\nRevenue Allowances',
#    'Concentration of Revenue',
#    'Revenue for fiscal year 2024 was $60.9 billion, up 126% from a year ago.',
#    'Revenue: (In millions)\nData Center 47,525 15,005 $ 10,613\nGaming 10,447 9,067 12,462\nProfessional Visualization 1,553 1,544 2,111\nAutomotive 1,091 903 566\nOEM and Other 306 455 1,162\n60,922 26,974 $ 26,914',
#    '(2) Deferred revenue primarily includes customer advances and deferrals related to support for hardware and software, license and development arrangements, and cloud services. $233 million and\n$35 million of the balance in fiscal 2024 and 2023 respectively, related to customer advances.',
#    'invoiced in future periods. Revenue allocated to remaining performance obligations, which includes deferred revenue and amounts that will be invoiced and\nrecognized as revenue in future periods, was $1.1 billion as of January 28, 2024. We expect to recognize approximately 40% of this revenue over the next\ntwelve months and the remainder thereafter. This excludes revenue related to performance obligations for contracts with a length of one year or less.']],
#  'uris': None,
#  'data': None}

# %%
res_db = collection.query(query_texts=[query])["documents"][0][0:10]
context = ' '.join(res_db).replace("\n", " ")
context
# Out:
# 'Total revenue Total revenue $ 60,922 $ 26,974 $ 26,914 Revenue Recognition Product Sales Revenue Revenue Recognition Revenue Allowances Concentration of Revenue Revenue for fiscal year 2024 was $60.9 billion, up 126% from a year ago. Revenue: (In millions) Data Center 47,525 15,005 $ 10,613 Gaming 10,447 9,067 12,462 Professional Visualization 1,553 1,544 2,111 Automotive 1,091 903 566 OEM and Other 306 455 1,162 60,922 26,974 $ 26,914 (2) Deferred revenue primarily includes customer advances and deferrals related to support for hardware and software, license and development arrangements, and cloud services. $233 million and $35 million of the balance in fiscal 2024 and 2023 respectively, related to customer advances. invoiced in future periods. Revenue allocated to remaining performance obligations, which includes deferred revenue and amounts that will be invoiced and recognized as revenue in future periods, was $1.1 billion as of January 28, 2024. We expect to recognize approximately 40% of this revenue over the next twelve months and the remainder thereafter. This excludes revenue related to performance obligations for contracts with a length of one year or less.'

# %% [markdown]
# ### LLM Chat

# %%
# Chat with Context only
res = ollama.chat(model="phi3", 
                  messages=[{"role":"system", "content":"Give the most accurate answer using only \
                                                         the following information: \n"+context},
                            {"role":"user", "content":query}])
print(res["message"]["content"])
# Out:
# The total recognized revenue as mentioned in the information provided stands at $26,914 million (or about $26.9 billion) for fiscal year 2selfy 2024. However, it's worth noting that this figure does not include deferred revenue amounts or revenues related to performance obligations with a contract length of one year or less as they will be recognized in future periods based on the completion of certain milestones and deliveries.

# %%
# Chat with knowledge + Context
res = ollama.chat(model="phi3", 
                  messages=[{"role":"system", "content":"Give the most accurate answer using your knowledge \
                                                         and the following additional information: \n"+context},
                            {"role":"user", "content":query}])
print(res["message"]["content"])
# Out:
# The total reported revenue as per the information provided is $60,922 million (or $60.9 billion). This figure represents the overall earnings before considering deferred and unearned revenues that will be recognized in future periods based on performance obligations. Revenue recognition for these specific items depends on the completion of those services or fulfillment of contract terms, with estimates suggesting around 40% to be realized within the upcoming year following this fiscal cycle ending January 28, 2024.

# %%
# Chat Stream
res = ollama.chat(model="phi3", 
                  messages=[{"role":"system", "content":"Give the most accurate answer using your knowledge \
                                                         and the folling additional information: \n"+context},
                            {"role":"user", "content":query}],
                  stream=True)
for chunk in res:
    print(chunk["message"]["content"], end="")
# Out:
# The total recognized revenue provided in your information is $26,914 million as of January 28, 2curing fiscal year (FY) 2024 for Dell Technologies. This amount reflects a significant increase from the previous period wherein deferred revenue was also substantial due to customer advances and support obligations that have yet to be recognized in accordance with accounting principles, which are expected to generate $1.1 billion over twelve months following recognition of such as part for performance obligations on longer contracts beyond a year's duration from the fiscal period ending January 28, 2024.
